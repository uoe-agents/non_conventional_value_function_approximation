# %%
import gym 
import numpy as np
from custom_envs.gridworlds import WindyGridworldEnv, SimpleGridworldEnv
from custom_envs.mountain_car import MountainCarEnv

from function_approximators.function_approximators import NeuralNetwork, LinearModel, DecisionTree, RandomForest, SupportVectorRegressor, KNeighboursRegressor, GaussianProcess, OnlineGaussianProcess
from sklearn.gaussian_process.kernels import RBF, ConstantKernel, RationalQuadratic, Matern
from sklearn.metrics.pairwise import rbf_kernel, chi2_kernel, laplacian_kernel 

from utils.train_utils import train, solve, train_time
from utils.plot_utils import plot_returns

from agents.av_agents import DQNAgent, LinearAgent, FQIAgent, OnlineGaussianProccessAgent

import operator

# %%
function_approximators = [NeuralNetwork, LinearModel, DecisionTree, RandomForest, SupportVectorRegressor, KNeighboursRegressor, GaussianProcess, OnlineGaussianProcess]

agents = [DQNAgent, LinearAgent, *[FQIAgent]*5, OnlineGaussianProccessAgent]

RENDER = False
env = gym.make("CartPole-v1")
# env = gym.make("Acrobot-v1")
# env = gym.make("MountainCar-v0")
# env = WindyGridworldEnv()
# env = gym.make("LunarLander-v2")
# env = SimpleGridworldEnv()
# env = MountainCarEnv()

# %%
# DQN Config
CONFIG_DQN = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "learning_rate": 0.00075,
    "hidden_size": (32,32),
    "target_update_freq": 200,
    "batch_size": 32,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "plot_loss": False,
    "epsilon": 1,
    "max_deduct": 0.97,
    "decay": 0.25,
    "lr_step_size": 1000,
    "lr_gamma": 0.95,
    "max_steps": 200,
    "non_param": False,
}

# Linear Config
CONFIG_LINEAR = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "learning_rate": 0.02,
    "target_update_freq": 50,
    "batch_size": 32,
    "gamma": 0.99,
    "buffer_capacity": int(1e7),
    "plot_loss": False,
    "epsilon": 1,
    "max_steps": 200,
    "poly_degree": 2,
    "max_deduct": 0.97,
    "decay": 0.5,
    "lr_step_size": 1000,
    "lr_gamma": 0.99,
    "non_param": False,
}

# Decision Tree Config
CONFIG_DT = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "model_save_freq": 1000,
    "model_save_capacity": 20,
    "update_freq": 1,
    "batch_size": 512,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.4,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"criterion":"mse","max_depth": 10, "min_samples_split": 20, "min_samples_leaf": 5},
    "feature_names": ["Cart Position", "Cart Velocity", "Pole Angle", "Pole Angular Velocity", "Action: Push Left", "Action: Push Right"],
    "plot_name": "dt_depth=8",
}

# Random Forest Config
CONFIG_RF = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 5,
    "model_save_freq": 1000,
    "model_save_capacity": 20,
    "update_freq": 5,
    "batch_size": 512,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.4,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"n_estimators": 10,"max_depth": 10, "min_samples_split": 20, "min_samples_leaf": 5},
}

# Support Vector Regressor Config
CONFIG_SVR = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "model_save_freq": 1000,
    "model_save_capacity": 20,
    "update_freq": 1,
    "batch_size": 512,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.3,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"kernel":"rbf", "degree": 2, "C": 2},
}


# K-Neighbors Regressor Config
CONFIG_KNR = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 5,
    "model_save_freq": 1000,
    "model_save_capacity": 20,
    "update_freq": 1,
    "batch_size": 256,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.3,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"n_neighbors":7, "weights": "distance", "algorithm": "auto", "leaf_size": 30},
}

# Gaussian Process Config
CONFIG_GP = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 5,
    "model_save_freq": 1000,
    "model_save_capacity": 20,
    "update_freq": 10,
    "batch_size": 512,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.3,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"alpha": 1e-10, "normalize_y": False, "kernel":  RBF(length_scale=0.08, length_scale_bounds="fixed")},
}

# Online Gaussian Process Config
CONFIG_GP_Online = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "batch_size": 32,
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.3,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"sigma_0": 0.5, "kernel":  rbf_kernel, "epsilon_tol": 0.05, "basis_limit": 1000},
}

# %%
returns = []
train_returns = []
train_times = []
n_seeds=9

j=7
for i in range(n_seeds):
    print(f"\n Run: {i+1} \n")
    r, _, t, times = train(env, 
            CONFIG_GP_Online, 
            fa=function_approximators[j], 
            agent = agents[j], 
            render=RENDER,
            online=True)
    env.close()
    returns.append(r)
    train_returns.append(t)
    train_times.append(times)
# Out:
#   0%|          | 41/20000 [00:00<00:48, 409.50it/s]
#  Run: 1
#
#   5%|▌         | 1017/20000 [00:07<02:51, 110.88it/s]Evaluation at timestep 1017 returned a mean returns of 151.70000000000002
# Epsilon = 0.8443583333333333
# Support Points = 792
#  10%|█         | 2038/20000 [00:21<05:18, 56.34it/s]Evaluation at timestep 2038 returned a mean returns of 200.0
# Epsilon = 0.6846
# Support Points = 1203
#  16%|█▌        | 3127/20000 [00:38<04:13, 66.56it/s]Evaluation at timestep 3127 returned a mean returns of 199.7
# Epsilon = 0.525475
# Support Points = 1436
#  20%|██        | 4043/20000 [01:00<05:43, 46.41it/s]Evaluation at timestep 4043 returned a mean returns of 196.5
# Epsilon = 0.36682500000000007
# Support Points = 1711
#  26%|██▌       | 5190/20000 [01:30<05:53, 41.86it/s]Evaluation at timestep 5190 returned a mean returns of 200.0
# Epsilon = 0.20991666666666675
# Support Points = 1965
#  31%|███       | 6190/20000 [01:58<06:01, 38.21it/s]Evaluation at timestep 6190 returned a mean returns of 200.0
# Epsilon = 0.051583333333333425
# Support Points = 2119
#  36%|███▌      | 7190/20000 [02:20<04:35, 46.49it/s]Evaluation at timestep 7190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2160
#  41%|████      | 8190/20000 [02:41<03:55, 50.18it/s]Evaluation at timestep 8190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2178
#  46%|████▌     | 9190/20000 [03:02<03:31, 51.11it/s]Evaluation at timestep 9190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2186
#  51%|█████     | 10190/20000 [03:24<03:28, 47.06it/s]Evaluation at timestep 10190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2212
#  56%|█████▌    | 11190/20000 [03:44<02:58, 49.48it/s]Evaluation at timestep 11190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2220
#  61%|██████    | 12190/20000 [04:07<02:45, 47.06it/s]Evaluation at timestep 12190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2241
#  66%|██████▌   | 13190/20000 [04:30<02:30, 45.34it/s]Evaluation at timestep 13190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2261
#  71%|███████   | 14190/20000 [04:53<02:06, 45.86it/s]Evaluation at timestep 14190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2268
#  76%|███████▌  | 15190/20000 [05:14<01:37, 49.44it/s]Evaluation at timestep 15190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2270
#  81%|████████  | 16190/20000 [05:37<01:22, 46.36it/s]Evaluation at timestep 16190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2294
#  86%|████████▌ | 17190/20000 [06:00<01:00, 46.56it/s]Evaluation at timestep 17190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2304
#  91%|█████████ | 18190/20000 [06:24<00:41, 43.73it/s]Evaluation at timestep 18190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2332
#  96%|█████████▌| 19190/20000 [06:46<00:17, 46.00it/s]Evaluation at timestep 19190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2339
# 20190it [07:09, 46.98it/s]
#   0%|          | 19/20000 [00:00<02:01, 164.89it/s]Evaluation at timestep 20190 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2345
#
#  Run: 2
#
#   5%|▌         | 1024/20000 [00:09<04:00, 78.95it/s]Evaluation at timestep 1024 returned a mean returns of 200.0
# Epsilon = 0.8461
# Support Points = 855
#  10%|█         | 2020/20000 [00:23<04:33, 65.64it/s]Evaluation at timestep 2020 returned a mean returns of 200.0
# Epsilon = 0.6979
# Support Points = 1183
#  15%|█▌        | 3021/20000 [00:43<06:08, 46.02it/s]Evaluation at timestep 3021 returned a mean returns of 169.20000000000002
# Epsilon = 0.5294333333333334
# Support Points = 1532
#  20%|██        | 4036/20000 [01:13<07:11, 37.02it/s]Evaluation at timestep 4036 returned a mean returns of 199.7
# Epsilon = 0.3926333333333334
# Support Points = 1866
#  25%|██▌       | 5046/20000 [01:43<06:58, 35.74it/s]Evaluation at timestep 5046 returned a mean returns of 195.0
# Epsilon = 0.22907500000000003
# Support Points = 2090
#  30%|███       | 6022/20000 [02:09<05:31, 42.21it/s]Evaluation at timestep 6022 returned a mean returns of 195.9
# Epsilon = 0.07818333333333338
# Support Points = 2170
#  35%|███▌      | 7022/20000 [02:34<05:12, 41.52it/s]Evaluation at timestep 7022 returned a mean returns of 198.7
# Epsilon = 0.050000000000000044
# Support Points = 2228
#  40%|████      | 8009/20000 [03:01<05:16, 37.90it/s]Evaluation at timestep 8009 returned a mean returns of 199.5
# Epsilon = 0.050000000000000044
# Support Points = 2299
#  45%|████▌     | 9003/20000 [03:25<04:20, 42.24it/s]Evaluation at timestep 9003 returned a mean returns of 197.7
# Epsilon = 0.050000000000000044
# Support Points = 2326
#  51%|█████     | 10194/20000 [03:54<03:53, 42.05it/s]Evaluation at timestep 10194 returned a mean returns of 198.1
# Epsilon = 0.050000000000000044
# Support Points = 2360
#  56%|█████▌    | 11184/20000 [04:19<03:28, 42.31it/s]Evaluation at timestep 11184 returned a mean returns of 198.70000000000002
# Epsilon = 0.050000000000000044
# Support Points = 2387
#  61%|██████    | 12154/20000 [04:47<03:22, 38.73it/s]Evaluation at timestep 12154 returned a mean returns of 199.1
# Epsilon = 0.050000000000000044
# Support Points = 2406
#  66%|██████▌   | 13148/20000 [05:12<02:44, 41.64it/s]Evaluation at timestep 13148 returned a mean returns of 199.6
# Epsilon = 0.050000000000000044
# Support Points = 2431
#  71%|███████   | 14138/20000 [05:37<02:22, 41.15it/s]Evaluation at timestep 14138 returned a mean returns of 199.6
# Epsilon = 0.050000000000000044
# Support Points = 2447
#  76%|███████▌  | 15138/20000 [06:02<01:56, 41.68it/s]Evaluation at timestep 15138 returned a mean returns of 197.7
# Epsilon = 0.050000000000000044
# Support Points = 2451
#  81%|████████  | 16119/20000 [06:28<01:36, 40.18it/s]Evaluation at timestep 16119 returned a mean returns of 198.8
# Epsilon = 0.050000000000000044
# Support Points = 2469
#  86%|████████▌ | 17114/20000 [06:53<01:10, 41.11it/s]Evaluation at timestep 17114 returned a mean returns of 198.79999999999998
# Epsilon = 0.050000000000000044
# Support Points = 2477
#  90%|█████████ | 18073/20000 [07:19<00:50, 38.23it/s]Evaluation at timestep 18073 returned a mean returns of 197.5
# Epsilon = 0.050000000000000044
# Support Points = 2489
#  95%|█████████▌| 19068/20000 [07:45<00:22, 40.59it/s]Evaluation at timestep 19068 returned a mean returns of 199.6
# Epsilon = 0.050000000000000044
# Support Points = 2499
# 20066it [08:10, 40.89it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]Evaluation at timestep 20066 returned a mean returns of 199.1
# Epsilon = 0.050000000000000044
# Support Points = 2505
#
#  Run: 3
#
#   5%|▌         | 1003/20000 [00:08<03:01, 104.59it/s]Evaluation at timestep 1003 returned a mean returns of 163.0
# Epsilon = 0.8511666666666666
# Support Points = 790
#  10%|█         | 2027/20000 [00:23<04:06, 72.77it/s]Evaluation at timestep 2027 returned a mean returns of 192.8
# Epsilon = 0.6857083333333334
# Support Points = 1188
#  15%|█▌        | 3060/20000 [00:46<06:32, 43.11it/s]Evaluation at timestep 3060 returned a mean returns of 200.0
# Epsilon = 0.53165
# Support Points = 1556
#  20%|██        | 4079/20000 [01:11<05:31, 48.10it/s]Evaluation at timestep 4079 returned a mean returns of 195.3
# Epsilon = 0.3858250000000001
# Support Points = 1766
#  26%|██▌       | 5133/20000 [01:40<05:42, 43.45it/s]Evaluation at timestep 5133 returned a mean returns of 200.0
# Epsilon = 0.2189416666666667
# Support Points = 1978
#  30%|███       | 6091/20000 [02:03<05:23, 42.96it/s]Evaluation at timestep 6091 returned a mean returns of 199.5
# Epsilon = 0.06725833333333342
# Support Points = 2060
#  35%|███▌      | 7091/20000 [02:26<04:47, 44.85it/s]Evaluation at timestep 7091 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2114
#  40%|████      | 8081/20000 [02:47<04:06, 48.43it/s]Evaluation at timestep 8081 returned a mean returns of 199.7
# Epsilon = 0.050000000000000044
# Support Points = 2139
#  45%|████▌     | 9081/20000 [03:10<03:56, 46.21it/s]Evaluation at timestep 9081 returned a mean returns of 195.0
# Epsilon = 0.050000000000000044
# Support Points = 2180
#  50%|█████     | 10081/20000 [03:33<03:35, 46.06it/s]Evaluation at timestep 10081 returned a mean returns of 199.3
# Epsilon = 0.050000000000000044
# Support Points = 2219
#  55%|█████▌    | 11079/20000 [03:58<03:25, 43.34it/s]Evaluation at timestep 11079 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2248
#  60%|██████    | 12079/20000 [04:20<02:50, 46.36it/s]Evaluation at timestep 12079 returned a mean returns of 195.0
# Epsilon = 0.050000000000000044
# Support Points = 2256
#  65%|██████▌   | 13079/20000 [04:43<02:26, 47.13it/s]Evaluation at timestep 13079 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2260
#  70%|███████   | 14072/20000 [05:05<02:05, 47.05it/s]Evaluation at timestep 14072 returned a mean returns of 198.8
# Epsilon = 0.050000000000000044
# Support Points = 2274
#  75%|███████▌  | 15059/20000 [05:28<01:47, 45.84it/s]Evaluation at timestep 15059 returned a mean returns of 196.2
# Epsilon = 0.050000000000000044
# Support Points = 2290
#  80%|████████  | 16029/20000 [05:50<01:27, 45.44it/s]Evaluation at timestep 16029 returned a mean returns of 196.70000000000002
# Epsilon = 0.050000000000000044
# Support Points = 2300
#  85%|████████▌ | 17029/20000 [06:12<01:02, 47.56it/s]Evaluation at timestep 17029 returned a mean returns of 198.8
# Epsilon = 0.050000000000000044
# Support Points = 2304
#  91%|█████████ | 18185/20000 [06:39<00:39, 46.45it/s]Evaluation at timestep 18185 returned a mean returns of 197.1
# Epsilon = 0.050000000000000044
# Support Points = 2320
#  96%|█████████▌| 19172/20000 [07:01<00:18, 45.59it/s]Evaluation at timestep 19172 returned a mean returns of 195.70000000000002
# Epsilon = 0.050000000000000044
# Support Points = 2326
# 20152it [07:24, 45.34it/s]
#   0%|          | 32/20000 [00:00<01:03, 313.03it/s]Evaluation at timestep 20152 returned a mean returns of 195.20000000000002
# Epsilon = 0.050000000000000044
# Support Points = 2336
#
#  Run: 4
#
#   5%|▌         | 1012/20000 [00:10<04:18, 73.54it/s]Evaluation at timestep 1012 returned a mean returns of 200.0
# Epsilon = 0.8437250000000001
# Support Points = 847
#  10%|█         | 2045/20000 [00:27<04:34, 65.53it/s]Evaluation at timestep 2045 returned a mean returns of 200.0
# Epsilon = 0.6857083333333334
# Support Points = 1240
#  16%|█▌        | 3106/20000 [00:51<06:10, 45.56it/s]Evaluation at timestep 3106 returned a mean returns of 200.0
# Epsilon = 0.5257916666666667
# Support Points = 1605
#  20%|██        | 4063/20000 [01:16<06:07, 43.33it/s]Evaluation at timestep 4063 returned a mean returns of 200.0
# Epsilon = 0.38835833333333336
# Support Points = 1843
#  25%|██▌       | 5046/20000 [01:32<04:10, 59.79it/s]Evaluation at timestep 5046 returned a mean returns of 198.0
# Epsilon = 0.23271666666666668
# Support Points = 1863
#  30%|███       | 6046/20000 [01:52<03:58, 58.53it/s]Evaluation at timestep 6046 returned a mean returns of 200.0
# Epsilon = 0.07438333333333336
# Support Points = 1905
#  35%|███▌      | 7046/20000 [02:10<03:36, 59.74it/s]Evaluation at timestep 7046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1920
#  40%|████      | 8046/20000 [02:28<03:10, 62.82it/s]Evaluation at timestep 8046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1920
#  45%|████▌     | 9046/20000 [02:45<02:51, 63.79it/s]Evaluation at timestep 9046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1920
#  50%|█████     | 10046/20000 [03:04<02:52, 57.65it/s]Evaluation at timestep 10046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1920
#  55%|█████▌    | 11046/20000 [03:26<03:00, 49.62it/s]Evaluation at timestep 11046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1982
#  60%|██████    | 12046/20000 [03:44<02:19, 57.17it/s]Evaluation at timestep 12046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1982
#  65%|██████▌   | 13046/20000 [04:01<01:55, 60.02it/s]Evaluation at timestep 13046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1982
#  70%|███████   | 14046/20000 [04:19<01:37, 60.79it/s]Evaluation at timestep 14046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1982
#  75%|███████▌  | 15046/20000 [04:37<01:21, 60.98it/s]Evaluation at timestep 15046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1982
#  80%|████████  | 16046/20000 [04:55<01:04, 60.97it/s]Evaluation at timestep 16046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1982
#  85%|████████▌ | 17046/20000 [05:13<00:48, 60.74it/s]Evaluation at timestep 17046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1982
#  90%|█████████ | 18046/20000 [05:31<00:33, 57.99it/s]Evaluation at timestep 18046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1992
#  95%|█████████▌| 19046/20000 [05:49<00:16, 59.14it/s]Evaluation at timestep 19046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1992
# 20046it [06:07, 54.49it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]Evaluation at timestep 20046 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1992
#
#  Run: 5
#
#   5%|▌         | 1001/20000 [00:12<04:30, 70.32it/s]Evaluation at timestep 1001 returned a mean returns of 200.0
# Epsilon = 0.8446750000000001
# Support Points = 823
#  10%|█         | 2044/20000 [00:29<05:15, 56.97it/s]Evaluation at timestep 2044 returned a mean returns of 192.6
# Epsilon = 0.6895083333333334
# Support Points = 1208
#  15%|█▌        | 3002/20000 [00:44<03:54, 72.56it/s]Evaluation at timestep 3002 returned a mean returns of 197.8
# Epsilon = 0.5473250000000001
# Support Points = 1382
#  20%|██        | 4035/20000 [01:05<06:15, 42.54it/s]Evaluation at timestep 4035 returned a mean returns of 197.4
# Epsilon = 0.3875666666666666
# Support Points = 1528
#  26%|██▌       | 5120/20000 [01:28<05:18, 46.76it/s]Evaluation at timestep 5120 returned a mean returns of 156.6
# Epsilon = 0.22100000000000009
# Support Points = 1675
#  30%|███       | 6080/20000 [01:51<04:48, 48.28it/s]Evaluation at timestep 6080 returned a mean returns of 126.3
# Epsilon = 0.06900000000000006
# Support Points = 1834
#  35%|███▌      | 7015/20000 [02:20<05:40, 38.15it/s]Evaluation at timestep 7015 returned a mean returns of 148.60000000000002
# Epsilon = 0.050000000000000044
# Support Points = 2019
#  40%|████      | 8093/20000 [02:49<05:07, 38.67it/s]Evaluation at timestep 8093 returned a mean returns of 142.20000000000002
# Epsilon = 0.050000000000000044
# Support Points = 2110
#  45%|████▌     | 9095/20000 [03:14<04:09, 43.66it/s]Evaluation at timestep 9095 returned a mean returns of 129.99999999999997
# Epsilon = 0.050000000000000044
# Support Points = 2169
#  50%|█████     | 10043/20000 [03:43<04:27, 37.28it/s]Evaluation at timestep 10043 returned a mean returns of 150.4
# Epsilon = 0.050000000000000044
# Support Points = 2272
#  55%|█████▌    | 11042/20000 [04:06<03:20, 44.69it/s]Evaluation at timestep 11042 returned a mean returns of 115.0
# Epsilon = 0.050000000000000044
# Support Points = 2295
#  60%|██████    | 12077/20000 [04:35<03:36, 36.56it/s]Evaluation at timestep 12077 returned a mean returns of 121.80000000000001
# Epsilon = 0.050000000000000044
# Support Points = 2357
#  65%|██████▌   | 13042/20000 [05:02<03:14, 35.74it/s]Evaluation at timestep 13042 returned a mean returns of 105.59999999999998
# Epsilon = 0.050000000000000044
# Support Points = 2417
#  70%|███████   | 14049/20000 [05:31<02:37, 37.80it/s]Evaluation at timestep 14049 returned a mean returns of 126.79999999999998
# Epsilon = 0.050000000000000044
# Support Points = 2457
#  75%|███████▌  | 15033/20000 [05:56<01:57, 42.14it/s]Evaluation at timestep 15033 returned a mean returns of 122.3
# Epsilon = 0.050000000000000044
# Support Points = 2461
#  80%|████████  | 16080/20000 [06:24<01:37, 40.35it/s]Evaluation at timestep 16080 returned a mean returns of 99.10000000000001
# Epsilon = 0.050000000000000044
# Support Points = 2479
#  85%|████████▌ | 17005/20000 [06:50<01:28, 33.88it/s]Evaluation at timestep 17005 returned a mean returns of 107.50000000000001
# Epsilon = 0.050000000000000044
# Support Points = 2515
#  90%|█████████ | 18018/20000 [07:19<00:53, 37.04it/s]Evaluation at timestep 18018 returned a mean returns of 112.0
# Epsilon = 0.050000000000000044
# Support Points = 2545
#  95%|█████████▌| 19047/20000 [07:48<00:25, 36.93it/s]Evaluation at timestep 19047 returned a mean returns of 105.59999999999998
# Epsilon = 0.050000000000000044
# Support Points = 2563
# 20100it [08:16, 40.46it/s]
#   0%|          | 39/20000 [00:00<01:13, 270.23it/s]Evaluation at timestep 20100 returned a mean returns of 101.1
# Epsilon = 0.050000000000000044
# Support Points = 2570
#
#  Run: 6
#
#   5%|▌         | 1007/20000 [00:09<03:37, 87.38it/s]Evaluation at timestep 1007 returned a mean returns of 46.199999999999996
# Epsilon = 0.8426166666666667
# Support Points = 765
#  10%|█         | 2036/20000 [00:25<05:15, 56.87it/s]Evaluation at timestep 2036 returned a mean returns of 140.2
# Epsilon = 0.6844416666666666
# Support Points = 1148
#  15%|█▌        | 3015/20000 [00:45<06:40, 42.37it/s]Evaluation at timestep 3015 returned a mean returns of 200.0
# Epsilon = 0.52595
# Support Points = 1500
#  20%|██        | 4013/20000 [01:13<08:11, 32.56it/s]Evaluation at timestep 4013 returned a mean returns of 200.0
# Epsilon = 0.3676166666666667
# Support Points = 1793
#  26%|██▌       | 5130/20000 [01:42<06:00, 41.20it/s]Evaluation at timestep 5130 returned a mean returns of 200.0
# Epsilon = 0.2194166666666667
# Support Points = 1961
#  31%|███       | 6130/20000 [02:07<05:30, 42.03it/s]Evaluation at timestep 6130 returned a mean returns of 200.0
# Epsilon = 0.06108333333333338
# Support Points = 2042
#  36%|███▌      | 7130/20000 [02:33<05:01, 42.73it/s]Evaluation at timestep 7130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2114
#  41%|████      | 8130/20000 [02:58<04:41, 42.13it/s]Evaluation at timestep 8130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2180
#  46%|████▌     | 9130/20000 [03:21<03:53, 46.60it/s]Evaluation at timestep 9130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2198
#  51%|█████     | 10130/20000 [03:43<03:26, 47.83it/s]Evaluation at timestep 10130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2211
#  56%|█████▌    | 11130/20000 [04:04<03:02, 48.59it/s]Evaluation at timestep 11130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2224
#  61%|██████    | 12130/20000 [04:32<03:04, 42.70it/s]Evaluation at timestep 12130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2242
#  66%|██████▌   | 13130/20000 [04:55<02:35, 44.24it/s]Evaluation at timestep 13130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2243
#  71%|███████   | 14130/20000 [05:18<02:08, 45.74it/s]Evaluation at timestep 14130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2255
#  76%|███████▌  | 15130/20000 [05:40<01:42, 47.53it/s]Evaluation at timestep 15130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2256
#  81%|████████  | 16130/20000 [06:03<01:23, 46.45it/s]Evaluation at timestep 16130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2272
#  86%|████████▌ | 17130/20000 [06:25<00:59, 48.22it/s]Evaluation at timestep 17130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2274
#  91%|█████████ | 18130/20000 [06:48<00:40, 46.72it/s]Evaluation at timestep 18130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2282
#  96%|█████████▌| 19130/20000 [07:12<00:19, 43.56it/s]Evaluation at timestep 19130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2289
# 20130it [07:35, 44.19it/s]
#   0%|          | 39/20000 [00:00<01:19, 252.23it/s]Evaluation at timestep 20130 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2289
#
#  Run: 7
#
#   5%|▌         | 1000/20000 [00:13<04:38, 68.28it/s]Evaluation at timestep 1000 returned a mean returns of 109.7
# Epsilon = 0.8449916666666667
# Support Points = 787
#  10%|█         | 2003/20000 [00:30<05:10, 57.91it/s]Evaluation at timestep 2003 returned a mean returns of 200.0
# Epsilon = 0.6909333333333334
# Support Points = 1157
#  15%|█▌        | 3029/20000 [00:48<04:00, 70.54it/s]Evaluation at timestep 3029 returned a mean returns of 200.0
# Epsilon = 0.5459
# Support Points = 1371
#  20%|██        | 4018/20000 [01:07<04:44, 56.19it/s]Evaluation at timestep 4018 returned a mean returns of 200.0
# Epsilon = 0.3818666666666668
# Support Points = 1545
#  25%|██▌       | 5018/20000 [01:32<05:50, 42.71it/s]Evaluation at timestep 5018 returned a mean returns of 200.0
# Epsilon = 0.23714999999999997
# Support Points = 1776
#  30%|███       | 6018/20000 [01:52<04:22, 53.29it/s]Evaluation at timestep 6018 returned a mean returns of 200.0
# Epsilon = 0.07881666666666665
# Support Points = 1825
#  35%|███▌      | 7018/20000 [02:09<03:31, 61.47it/s]Evaluation at timestep 7018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1829
#  40%|████      | 8018/20000 [02:27<03:12, 62.37it/s]Evaluation at timestep 8018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1829
#  45%|████▌     | 9018/20000 [02:44<02:54, 62.97it/s]Evaluation at timestep 9018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1829
#  50%|█████     | 10018/20000 [03:02<02:39, 62.77it/s]Evaluation at timestep 10018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1829
#  55%|█████▌    | 11018/20000 [03:19<02:21, 63.34it/s]Evaluation at timestep 11018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1842
#  60%|██████    | 12018/20000 [03:36<02:05, 63.79it/s]Evaluation at timestep 12018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1842
#  65%|██████▌   | 13018/20000 [03:54<01:50, 63.20it/s]Evaluation at timestep 13018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1845
#  70%|███████   | 14018/20000 [04:15<02:03, 48.54it/s]Evaluation at timestep 14018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1917
#  75%|███████▌  | 15018/20000 [04:36<01:39, 49.96it/s]Evaluation at timestep 15018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1953
#  80%|████████  | 16018/20000 [04:54<01:09, 57.10it/s]Evaluation at timestep 16018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1953
#  85%|████████▌ | 17018/20000 [05:14<00:54, 54.61it/s]Evaluation at timestep 17018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1959
#  90%|█████████ | 18018/20000 [05:34<00:35, 55.19it/s]Evaluation at timestep 18018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 1983
#  95%|█████████▌| 19018/20000 [05:59<00:22, 44.06it/s]Evaluation at timestep 19018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2065
# 20018it [06:19, 52.79it/s]
#   0%|          | 23/20000 [00:00<01:36, 206.44it/s]Evaluation at timestep 20018 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2065
#
#  Run: 8
#
#   5%|▌         | 1027/20000 [00:14<04:48, 65.79it/s]Evaluation at timestep 1027 returned a mean returns of 141.60000000000002
# Epsilon = 0.8448333333333333
# Support Points = 800
#  10%|█         | 2056/20000 [00:32<04:45, 62.76it/s]Evaluation at timestep 2056 returned a mean returns of 198.7
# Epsilon = 0.6890333333333334
# Support Points = 1170
#  15%|█▌        | 3034/20000 [00:52<06:33, 43.14it/s]Evaluation at timestep 3034 returned a mean returns of 180.3
# Epsilon = 0.5364
# Support Points = 1465
#  20%|██        | 4007/20000 [01:19<07:12, 36.99it/s]Evaluation at timestep 4007 returned a mean returns of 200.0
# Epsilon = 0.37521666666666675
# Support Points = 1750
#  26%|██▌       | 5133/20000 [01:47<05:28, 45.25it/s]Evaluation at timestep 5133 returned a mean returns of 200.0
# Epsilon = 0.2189416666666667
# Support Points = 1884
#  31%|███       | 6133/20000 [02:12<05:14, 44.07it/s]Evaluation at timestep 6133 returned a mean returns of 200.0
# Epsilon = 0.060608333333333375
# Support Points = 1996
#  36%|███▌      | 7133/20000 [02:31<04:04, 52.57it/s]Evaluation at timestep 7133 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2003
#  41%|████      | 8133/20000 [02:58<04:51, 40.70it/s]Evaluation at timestep 8133 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2103
#  46%|████▌     | 9133/20000 [03:19<03:51, 47.02it/s]Evaluation at timestep 9133 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2106
#  51%|█████     | 10133/20000 [03:43<03:47, 43.33it/s]Evaluation at timestep 10133 returned a mean returns of 199.2
# Epsilon = 0.050000000000000044
# Support Points = 2148
#  56%|█████▌    | 11121/20000 [04:06<03:11, 46.45it/s]Evaluation at timestep 11121 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2173
#  61%|██████    | 12121/20000 [04:29<02:47, 46.92it/s]Evaluation at timestep 12121 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2193
#  66%|██████▌   | 13121/20000 [04:53<02:33, 44.71it/s]Evaluation at timestep 13121 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2238
#  71%|███████   | 14111/20000 [05:18<02:19, 42.33it/s]Evaluation at timestep 14111 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2272
#  76%|███████▌  | 15111/20000 [05:40<01:44, 46.64it/s]Evaluation at timestep 15111 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2273
#  81%|████████  | 16111/20000 [06:04<01:26, 44.76it/s]Evaluation at timestep 16111 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2284
#  86%|████████▌ | 17111/20000 [06:27<01:03, 45.33it/s]Evaluation at timestep 17111 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2285
#  91%|█████████ | 18106/20000 [06:53<00:47, 39.99it/s]Evaluation at timestep 18106 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2314
#  96%|█████████▌| 19106/20000 [07:17<00:20, 43.30it/s]Evaluation at timestep 19106 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2317
# 20105it [07:42, 43.48it/s]
#   0%|          | 38/20000 [00:00<01:25, 233.35it/s]Evaluation at timestep 20105 returned a mean returns of 200.0
# Epsilon = 0.050000000000000044
# Support Points = 2334
#
#  Run: 9
#
#   5%|▌         | 1010/20000 [00:14<05:21, 59.14it/s]Evaluation at timestep 1010 returned a mean returns of 120.6
# Epsilon = 0.8445166666666667
# Support Points = 818
#  10%|█         | 2036/20000 [00:34<05:57, 50.24it/s]Evaluation at timestep 2036 returned a mean returns of 196.9
# Epsilon = 0.6895083333333334
# Support Points = 1218
#  15%|█▌        | 3097/20000 [00:58<06:32, 43.03it/s]Evaluation at timestep 3097 returned a mean returns of 188.70000000000002
# Epsilon = 0.53925
# Support Points = 1533
#  21%|██        | 4162/20000 [01:26<05:13, 50.56it/s]Evaluation at timestep 4162 returned a mean returns of 158.1
# Epsilon = 0.3715750000000001
# Support Points = 1739
#  26%|██▌       | 5190/20000 [01:48<04:52, 50.70it/s]Evaluation at timestep 5190 returned a mean returns of 175.3
# Epsilon = 0.20991666666666675
# Support Points = 1814
#  30%|███       | 6080/20000 [02:06<04:20, 53.49it/s]Evaluation at timestep 6080 returned a mean returns of 171.0
# Epsilon = 0.06678333333333342
# Support Points = 1853
#  35%|███▌      | 7004/20000 [02:25<03:50, 56.30it/s]Evaluation at timestep 7004 returned a mean returns of 164.6
# Epsilon = 0.050000000000000044
# Support Points = 1877
#  40%|████      | 8043/20000 [02:46<03:38, 54.82it/s]Evaluation at timestep 8043 returned a mean returns of 164.29999999999998
# Epsilon = 0.050000000000000044
# Support Points = 1902
#  45%|████▌     | 9014/20000 [03:06<03:27, 52.90it/s]Evaluation at timestep 9014 returned a mean returns of 158.89999999999998
# Epsilon = 0.050000000000000044
# Support Points = 1935
#  51%|█████     | 10125/20000 [03:28<02:55, 56.32it/s]Evaluation at timestep 10125 returned a mean returns of 175.79999999999998
# Epsilon = 0.050000000000000044
# Support Points = 1947
#  56%|█████▌    | 11129/20000 [03:48<02:42, 54.74it/s]Evaluation at timestep 11129 returned a mean returns of 185.8
# Epsilon = 0.050000000000000044
# Support Points = 1963
#  61%|██████    | 12148/20000 [04:09<02:27, 53.25it/s]Evaluation at timestep 12148 returned a mean returns of 189.7
# Epsilon = 0.050000000000000044
# Support Points = 1983
#  66%|██████▌   | 13127/20000 [04:31<02:26, 46.85it/s]Evaluation at timestep 13127 returned a mean returns of 176.6
# Epsilon = 0.050000000000000044
# Support Points = 2026
#  70%|███████   | 14027/20000 [04:50<01:56, 51.22it/s]Evaluation at timestep 14027 returned a mean returns of 190.9
# Epsilon = 0.050000000000000044
# Support Points = 2027
#  76%|███████▌  | 15150/20000 [05:16<01:49, 44.31it/s]Evaluation at timestep 15150 returned a mean returns of 197.3
# Epsilon = 0.050000000000000044
# Support Points = 2077
#  80%|████████  | 16070/20000 [05:37<01:24, 46.45it/s]Evaluation at timestep 16070 returned a mean returns of 183.79999999999998
# Epsilon = 0.050000000000000044
# Support Points = 2077
#  85%|████████▌ | 17002/20000 [05:58<01:03, 47.57it/s]Evaluation at timestep 17002 returned a mean returns of 180.8
# Epsilon = 0.050000000000000044
# Support Points = 2091
#  91%|█████████ | 18136/20000 [06:22<00:37, 49.95it/s]Evaluation at timestep 18136 returned a mean returns of 172.39999999999998
# Epsilon = 0.050000000000000044
# Support Points = 2095
#  96%|█████████▌| 19162/20000 [06:46<00:17, 47.01it/s]Evaluation at timestep 19162 returned a mean returns of 187.5
# Epsilon = 0.050000000000000044
# Support Points = 2119
# 20088it [07:05, 47.19it/s]Evaluation at timestep 20088 returned a mean returns of 198.8
# Epsilon = 0.050000000000000044
# Support Points = 2120

# %%
with open(f'cartpole_eval_Gaussian Process (On+).csv', 'ab') as eval:
    for i in range(n_seeds):
        np.savetxt(eval, [returns[i]], delimiter=',')

# %%
with open(f'cartpole_train_Gaussian Process (On+).csv', 'ab') as train:
    for i in range(n_seeds):
        np.savetxt(train, [train_returns[i]], delimiter=',')
        np.savetxt(train, [train_times[i]], delimiter=',')

# %%
n_eps = []
n_steps = []
not_solved = []
n_seeds=30

j=7
for i in range(n_seeds):
    print(f"\n Run: {i+1} \n")
    s, e, n = solve(env, 
            CONFIG_GP_Online, 
            fa=function_approximators[j], 
            agent = agents[j],
            target_return=195,
            op=operator.ge, 
            render=RENDER,
            online=True)
    env.close()
    n_eps.append(e)
    n_steps.append(s)
    not_solved.append(n)
# Out:
#  Run: 1
#
# Ep. timesteps: 200
# Total timesteps: 3434
# Total episodes: 90
# Evaluation mean return: 197.4
#
#  Run: 2
#
# Ep. timesteps: 200
# Total timesteps: 1388
# Total episodes: 53
# Evaluation mean return: 195.9
#
#  Run: 3
#
# Ep. timesteps: 200
# Total timesteps: 360
# Total episodes: 14
# Evaluation mean return: 200.0
#
#  Run: 4
#
# Ep. timesteps: 200
# Total timesteps: 11329
# Total episodes: 168
# Evaluation mean return: 196.7
#
#  Run: 5
#
# Ep. timesteps: 200
# Total timesteps: 5993
# Total episodes: 134
# Evaluation mean return: 200.0
#
#  Run: 6
#
# Ep. timesteps: 200
# Total timesteps: 2807
# Total episodes: 82
# Evaluation mean return: 200.0
#
#  Run: 7
#
# Ep. timesteps: 200
# Total timesteps: 1367
# Total episodes: 49
# Evaluation mean return: 200.0
#
#  Run: 8
#
# Ep. timesteps: 200
# Total timesteps: 874
# Total episodes: 37
# Evaluation mean return: 200.0
#
#  Run: 9
#
# Ep. timesteps: 200
# Total timesteps: 2291
# Total episodes: 78
# Evaluation mean return: 200.0
#
#  Run: 10
#
# Ep. timesteps: 200
# Total timesteps: 740
# Total episodes: 28
# Evaluation mean return: 195.5
#
#  Run: 11
#
# Ep. timesteps: 200
# Total timesteps: 637
# Total episodes: 24
# Evaluation mean return: 200.0
#
#  Run: 12
#
# Ep. timesteps: 200
# Total timesteps: 1481
# Total episodes: 58
# Evaluation mean return: 200.0
#
#  Run: 13
#
# Ep. timesteps: 200
# Total timesteps: 1472
# Total episodes: 55
# Evaluation mean return: 200.0
#
#  Run: 14
#
# Ep. timesteps: 200
# Total timesteps: 1091
# Total episodes: 45
# Evaluation mean return: 200.0
#
#  Run: 15
#
# Ep. timesteps: 200
# Total timesteps: 2618
# Total episodes: 83
# Evaluation mean return: 200.0
#
#  Run: 16
#
# Ep. timesteps: 200
# Total timesteps: 1694
# Total episodes: 64
# Evaluation mean return: 200.0
#
#  Run: 17
#
# Ep. timesteps: 200
# Total timesteps: 1487
# Total episodes: 53
# Evaluation mean return: 200.0
#
#  Run: 18
#
# Ep. timesteps: 200
# Total timesteps: 2449
# Total episodes: 95
# Evaluation mean return: 200.0
#
#  Run: 19
#
# Ep. timesteps: 200
# Total timesteps: 15841
# Total episodes: 167
# Evaluation mean return: 195.0
#
#  Run: 20
#
#
#  Run: 21
#
# Ep. timesteps: 200
# Total timesteps: 1105
# Total episodes: 45
# Evaluation mean return: 200.0
#
#  Run: 22
#
# Ep. timesteps: 200
# Total timesteps: 75
# Total episodes: 3
# Evaluation mean return: 200.0
#
#  Run: 23
#
# Ep. timesteps: 200
# Total timesteps: 1669
# Total episodes: 60
# Evaluation mean return: 200.0
#
#  Run: 24
#
# Ep. timesteps: 200
# Total timesteps: 1309
# Total episodes: 53
# Evaluation mean return: 195.0
#
#  Run: 25
#
# Ep. timesteps: 194
# Total timesteps: 18818
# Total episodes: 199
# Evaluation mean return: 195.20000000000002
#
#  Run: 26
#
# Ep. timesteps: 200
# Total timesteps: 4057
# Total episodes: 105
# Evaluation mean return: 200.0
#
#  Run: 27
#
# Ep. timesteps: 200
# Total timesteps: 3785
# Total episodes: 96
# Evaluation mean return: 199.8
#
#  Run: 28
#
# Ep. timesteps: 200
# Total timesteps: 3539
# Total episodes: 105
# Evaluation mean return: 200.0
#
#  Run: 29
#
# Ep. timesteps: 200
# Total timesteps: 1553
# Total episodes: 59
# Evaluation mean return: 200.0
#
#  Run: 30
#
# Ep. timesteps: 200
# Total timesteps: 454
# Total episodes: 18
# Evaluation mean return: 200.0

# %%
with open(f'cartpole_se195_Gaussian Process Online.csv', 'ab') as se:
    np.savetxt(se, [n_eps], delimiter=',')
    np.savetxt(se, [n_steps], delimiter=',')
    np.savetxt(se, [not_solved], delimiter=',')

# %%
mean_eps = np.mean(n_eps)
std_eps = np.std(n_eps)
print(f"Average n_eps: {mean_eps}")
print(f"Std n_eps: {std_eps}")
print(f"St.error n_eps: {std_eps/np.sqrt(n_seeds)}")

mean_steps = np.mean(n_steps)
std_steps = np.std(n_steps)
print(f"Average n_steps: {mean_steps}0")
print(f"Std n_steps: {std_steps}")
print(f"St.error n_steps: {std_steps/np.sqrt(n_seeds)}")

print(f"Not solved: {np.sum(not_solved)} runs")
# Out:
# Average n_eps: 77.13333333333334
# Std n_eps: 47.77219088781906
# St.error n_eps: 8.721968856900416
# Average n_steps: 3211.03333333333330
# Std n_steps: 4515.506184126967
# St.error n_steps: 824.4148652001386
# Not solved: 1 runs

# %%
j = 10
time = train_time(env, 
        CONFIG_GP_Online, 
        fa=function_approximators[j], 
        agent = agents[j],
        online=True)
env.close()

print(time)
# Out:
# 20029it [06:32, 51.03it/s]200.0
# 392.48629212379456
