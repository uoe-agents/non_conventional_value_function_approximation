# %%
## Imports

import gym 
import numpy as np
from custom_envs.gridworlds import WindyGridworldEnv, HybridGridworldEnv

from function_approximators.function_approximators import NeuralNetwork, LinearModel, DecisionTree, RandomForest, SupportVectorRegressor, KNeighboursRegressor, GaussianProcess, OnlineGaussianProcess
from sklearn.gaussian_process.kernels import RBF
from sklearn.metrics.pairwise import rbf_kernel

from utils.train_utils import train, solve, train_time
from utils.plot_utils import plot_returns

from agents.ad_agents import DQNAgent, LinearAgent, FQIAgent, OnlineGaussianProccessAgent
import operator

# %%
## Environment

function_approximators = [NeuralNetwork, LinearModel, DecisionTree, RandomForest, SupportVectorRegressor, KNeighboursRegressor, GaussianProcess, OnlineGaussianProcess]

agents = [DQNAgent, LinearAgent, *[FQIAgent]*5, OnlineGaussianProccessAgent]

RENDER = False
# env = HybridGridworldEnv()
env = WindyGridworldEnv()

# %%
## Configuration Files

# DQN Config
CONFIG_DQN = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "learning_rate": 0.0007,
    "hidden_size": (64,64),
    "target_update_freq": 200,
    "batch_size": 32,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "plot_loss": False,
    "epsilon": 1,
    "max_deduct": 0.97,
    "decay": 0.3,
    "lr_step_size": 1000,
    "lr_gamma": 0.95,
    "max_steps": 200,
    "non_param": False,
}

# Linear Config
CONFIG_LINEAR = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "learning_rate": 0.02,
    "target_update_freq": 50,
    "batch_size": 32,
    "gamma": 0.99,
    "buffer_capacity": int(1e7),
    "plot_loss": False,
    "epsilon": 1,
    "max_steps": 200,
    "poly_degree": 1,
    "max_deduct": 0.97,
    "decay": 0.5,
    "lr_step_size": 1000,
    "lr_gamma": 0.99,
    "non_param": False,
}

# Decision Tree Config
CONFIG_DT = {
    "episode_length": 500,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "model_save_freq": 1000,
    "model_save_capacity": 20,
    "update_freq": 1,
    "batch_size": 128,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.9,
    "decay": 0.4,
    "max_steps": 500,
    "non_param": True,
    "model_params": {"criterion":"mse","max_depth": 200, "min_samples_split": 2, "min_samples_leaf": 1},
    "feature_names": ["Cart Position", "Cart Velocity", "Pole Angle", "Pole Angular Velocity", "Action: Push Left", "Action: Push Right"],
    "plot_name": "dt_depth=8",
}

# Random Forest Config
CONFIG_RF = {
    "episode_length": 500,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "model_save_freq": 5000,
    "model_save_capacity": 20,
    "update_freq": 1,
    "batch_size": 128,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.9,
    "decay": 0.4,
    "max_steps": 500,
    "non_param": True,
    "model_params": {"n_estimators": 5,"max_depth": 100, "min_samples_split": 2, "min_samples_leaf": 1},
}

# Support Vector Regressor Config
CONFIG_SVR = {
    "episode_length": 200,
    "max_timesteps": 50000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 1,
    "model_save_freq": 5000,
    "model_save_capacity": 20,
    "update_freq": 1,
    "batch_size": 64,
    "gamma": 0.99,
    "buffer_capacity": 512,
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.4,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"kernel":"rbf", "degree": 2, "C": 100},
}


# K-Neighbors Regressor Config
CONFIG_KNR = {
    "episode_length": 200,
    "max_timesteps": 100000,
    "max_time": 30 * 60,
    "eval_freq": 5000, 
    "eval_episodes": 1,
    "model_save_freq": 1000,
    "model_save_capacity": 5,
    "update_freq": 5,
    "batch_size": 64,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.4,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"n_neighbors":7, "weights": "distance", "algorithm": "auto", "leaf_size": 30},
}

# Gaussian Process Config
CONFIG_GP = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 1,
    "model_save_freq": 1000,
    "model_save_capacity": 5,
    "update_freq": 10,
    "batch_size": 512,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.5,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"alpha": 1e-10, "normalize_y": False, "kernel":  RBF(length_scale=0.5, length_scale_bounds="fixed")},
}

# Online Gaussian Process Config
CONFIG_GP_Online = {
    "episode_length": 200,
    "max_timesteps": 20000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 1,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "batch_size": 32,
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.5,
    "max_steps": 200,
    "non_param": True,
    "model_params": {"sigma_0": 0.5, "init":-200, "kernel":  rbf_kernel, "epsilon_tol": 0.045, "basis_limit": 1000},
}

CONFIGS = [CONFIG_DQN, CONFIG_LINEAR, CONFIG_DT, CONFIG_RF, CONFIG_SVR, CONFIG_KNR, CONFIG_GP, CONFIG_GP_Online]
onlines = [False, False, False, False, False, False, False, True]
models = ["Neural Network", "Linear Model", "Decision Tree", "Random Forest", "Support Vectors", "K-Neighbours", "Gaussian Process", "Gaussian Process Online"]

# %%
## Performance Evaluation

returns = []
train_returns = []
train_times = []
n_seeds=5

j=3
for i in range(n_seeds):
    print(f"\n Run: {i+1} \n")
    r, _, t, times = train(env, 
            CONFIGS[j], 
            fa=function_approximators[j], 
            agent = agents[j], 
            render=RENDER,
            online=onlines[j],
            threshold=0)
    env.close()
    returns.append(r)
    train_returns.append(t)
    train_times.append(times)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
#  Run: 1
#
#   5%|▌         | 1000/20000 [00:23<03:30, 90.48it/s]Evaluation at timestep 1000 returned a mean returns of -500.0
# Epsilon = 0.94375
# Replay Buffer count: 1230
#  10%|█         | 2048/20000 [00:44<07:46, 38.45it/s]Evaluation at timestep 2048 returned a mean returns of -15.999
# Epsilon = 0.7845625
# Replay Buffer count: 1490
#  15%|█▌        | 3042/20000 [01:21<10:40, 26.48it/s]Evaluation at timestep 3042 returned a mean returns of -15.999
# Epsilon = 0.6628375
# Replay Buffer count: 1840
#  20%|██        | 4063/20000 [02:02<10:38, 24.96it/s]Evaluation at timestep 4063 returned a mean returns of -15.999
# Epsilon = 0.5515749999999999
# Replay Buffer count: 1900
#  25%|██▌       | 5011/20000 [02:42<10:19, 24.19it/s]Evaluation at timestep 5011 returned a mean returns of -15.999
# Epsilon = 0.440875
# Replay Buffer count: 1930
#  30%|███       | 6008/20000 [03:24<09:54, 23.53it/s]Evaluation at timestep 6008 returned a mean returns of -15.999
# Epsilon = 0.32724999999999993
# Replay Buffer count: 1960
#  35%|███▌      | 7004/20000 [04:07<09:23, 23.06it/s]Evaluation at timestep 7004 returned a mean returns of -15.999
# Epsilon = 0.21407500000000002
# Replay Buffer count: 1960
#  40%|████      | 8012/20000 [04:51<08:38, 23.14it/s]Evaluation at timestep 8012 returned a mean returns of -15.999
# Epsilon = 0.10044999999999993
# Replay Buffer count: 1960
#  45%|████▌     | 9011/20000 [05:35<07:56, 23.06it/s]Evaluation at timestep 9011 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  50%|█████     | 10010/20000 [06:18<07:07, 23.38it/s]Evaluation at timestep 10010 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  55%|█████▌    | 11003/20000 [07:01<06:29, 23.12it/s]Evaluation at timestep 11003 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  60%|██████    | 12005/20000 [07:55<05:45, 23.13it/s]Evaluation at timestep 12005 returned a mean returns of -500.0
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  65%|██████▌   | 13018/20000 [08:39<05:02, 23.12it/s]Evaluation at timestep 13018 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  70%|███████   | 14015/20000 [09:23<04:22, 22.76it/s]Evaluation at timestep 14015 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  75%|███████▌  | 15000/20000 [10:07<03:36, 23.13it/s]Evaluation at timestep 15000 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  80%|████████  | 16008/20000 [10:51<02:52, 23.13it/s]Evaluation at timestep 16008 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  85%|████████▌ | 17014/20000 [11:35<02:09, 23.03it/s]Evaluation at timestep 17014 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  90%|█████████ | 18013/20000 [12:18<01:26, 23.07it/s]Evaluation at timestep 18013 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#  95%|█████████▌| 19009/20000 [13:02<00:42, 23.33it/s]Evaluation at timestep 19009 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
# 100%|██████████| 20000/20000 [13:45<00:00, 24.22it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]Evaluation at timestep 20000 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1960
#
#  Run: 2
#
#   6%|▋         | 1288/20000 [00:24<06:35, 47.31it/s]Evaluation at timestep 1288 returned a mean returns of -15.999
# Epsilon = 0.9110125
# Replay Buffer count: 1660
#  10%|█         | 2053/20000 [00:49<08:35, 34.83it/s]Evaluation at timestep 2053 returned a mean returns of -15.999
# Epsilon = 0.782875
# Replay Buffer count: 1760
#  15%|█▌        | 3013/20000 [01:28<11:24, 24.82it/s]Evaluation at timestep 3013 returned a mean returns of -14.999
# Epsilon = 0.6655375
# Replay Buffer count: 1990
#  20%|██        | 4024/20000 [02:13<12:19, 21.61it/s]Evaluation at timestep 4024 returned a mean returns of -14.999
# Epsilon = 0.5528124999999999
# Replay Buffer count: 2130
#  25%|██▌       | 5002/20000 [03:00<11:51, 21.07it/s]Evaluation at timestep 5002 returned a mean returns of -14.999
# Epsilon = 0.439975
# Replay Buffer count: 2150
#  30%|███       | 6022/20000 [03:49<11:17, 20.63it/s]Evaluation at timestep 6022 returned a mean returns of -14.999
# Epsilon = 0.3251125
# Replay Buffer count: 2170
#  35%|███▌      | 7011/20000 [04:37<10:33, 20.51it/s]Evaluation at timestep 7011 returned a mean returns of -14.999
# Epsilon = 0.21373750000000002
# Replay Buffer count: 2180
#  40%|████      | 8011/20000 [05:29<09:48, 20.38it/s]Evaluation at timestep 8011 returned a mean returns of -14.999
# Epsilon = 0.10134999999999994
# Replay Buffer count: 2180
#  45%|████▌     | 9001/20000 [06:18<08:58, 20.42it/s]Evaluation at timestep 9001 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  50%|█████     | 10005/20000 [07:07<08:08, 20.45it/s]Evaluation at timestep 10005 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  55%|█████▌    | 11008/20000 [07:57<07:20, 20.43it/s]Evaluation at timestep 11008 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  60%|██████    | 12002/20000 [08:46<06:36, 20.16it/s]Evaluation at timestep 12002 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  65%|██████▌   | 13000/20000 [09:36<05:47, 20.14it/s]Evaluation at timestep 13000 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  70%|███████   | 14007/20000 [10:27<05:02, 19.80it/s]Evaluation at timestep 14007 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  75%|███████▌  | 15014/20000 [11:17<04:05, 20.28it/s]Evaluation at timestep 15014 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  80%|████████  | 16002/20000 [12:06<03:17, 20.24it/s]Evaluation at timestep 16002 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  85%|████████▌ | 17005/20000 [12:56<02:26, 20.41it/s]Evaluation at timestep 17005 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  90%|█████████ | 18002/20000 [13:45<01:37, 20.41it/s]Evaluation at timestep 18002 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#  95%|█████████▌| 19013/20000 [14:35<00:48, 20.36it/s]Evaluation at timestep 19013 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
# 100%|██████████| 20000/20000 [15:24<00:00, 21.63it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]Evaluation at timestep 20000 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2180
#
#  Run: 3
#
#   5%|▌         | 1000/20000 [00:20<03:22, 93.82it/s]Evaluation at timestep 1000 returned a mean returns of -500.0
# Epsilon = 0.94375
# Replay Buffer count: 1350
#  10%|█         | 2000/20000 [00:44<05:31, 54.34it/s]Evaluation at timestep 2000 returned a mean returns of -500.0
# Epsilon = 0.83125
# Replay Buffer count: 1570
#  15%|█▌        | 3047/20000 [01:20<09:47, 28.84it/s]Evaluation at timestep 3047 returned a mean returns of -15.999
# Epsilon = 0.6650875
# Replay Buffer count: 1870
#  20%|██        | 4014/20000 [02:00<11:00, 24.21it/s]Evaluation at timestep 4014 returned a mean returns of -15.999
# Epsilon = 0.554275
# Replay Buffer count: 1960
#  25%|██▌       | 5014/20000 [02:46<11:51, 21.08it/s]Evaluation at timestep 5014 returned a mean returns of -15.999
# Epsilon = 0.43884999999999996
# Replay Buffer count: 2090
#  30%|███       | 6012/20000 [03:34<11:25, 20.42it/s]Evaluation at timestep 6012 returned a mean returns of -15.999
# Epsilon = 0.32657500000000006
# Replay Buffer count: 2100
#  35%|███▌      | 7013/20000 [04:23<10:35, 20.45it/s]Evaluation at timestep 7013 returned a mean returns of -15.999
# Epsilon = 0.21373750000000002
# Replay Buffer count: 2110
#  40%|████      | 8006/20000 [05:12<09:53, 20.19it/s]Evaluation at timestep 8006 returned a mean returns of -15.999
# Epsilon = 0.10112499999999991
# Replay Buffer count: 2110
#  45%|████▌     | 9005/20000 [06:02<09:00, 20.35it/s]Evaluation at timestep 9005 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2120
#  50%|█████     | 10021/20000 [06:53<08:13, 20.22it/s]Evaluation at timestep 10021 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2120
#  55%|█████▌    | 11017/20000 [07:43<07:29, 19.98it/s]Evaluation at timestep 11017 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2130
#  60%|██████    | 12002/20000 [08:32<06:36, 20.19it/s]Evaluation at timestep 12002 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2130
#  65%|██████▌   | 13009/20000 [09:23<05:48, 20.08it/s]Evaluation at timestep 13009 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2130
#  70%|███████   | 14003/20000 [10:13<05:15, 19.01it/s]Evaluation at timestep 14003 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2130
#  75%|███████▌  | 15006/20000 [11:04<04:24, 18.91it/s]Evaluation at timestep 15006 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2130
#  80%|████████  | 16010/20000 [11:54<03:18, 20.13it/s]Evaluation at timestep 16010 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2130
#  85%|████████▌ | 17001/20000 [12:43<02:28, 20.23it/s]Evaluation at timestep 17001 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2130
#  90%|█████████ | 18017/20000 [13:34<01:39, 20.01it/s]Evaluation at timestep 18017 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2140
#  95%|█████████▌| 19017/20000 [14:24<00:47, 20.52it/s]Evaluation at timestep 19017 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2140
# 20005it [15:14, 21.88it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]Evaluation at timestep 20005 returned a mean returns of -15.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2140
#
#  Run: 4
#
#   5%|▌         | 1000/20000 [00:24<04:36, 68.67it/s]Evaluation at timestep 1000 returned a mean returns of -500.0
# Epsilon = 0.94375
# Replay Buffer count: 1420
#  11%|█         | 2157/20000 [00:57<08:44, 33.99it/s]Evaluation at timestep 2157 returned a mean returns of -15.999
# Epsilon = 0.8135875
# Replay Buffer count: 1620
#  15%|█▌        | 3058/20000 [01:26<09:13, 30.61it/s]Evaluation at timestep 3058 returned a mean returns of -14.999
# Epsilon = 0.69085
# Replay Buffer count: 1780
#  20%|██        | 4030/20000 [02:01<09:51, 27.00it/s]Evaluation at timestep 4030 returned a mean returns of -14.999
# Epsilon = 0.5525875
# Replay Buffer count: 1850
#  25%|██▌       | 5011/20000 [02:40<10:04, 24.81it/s]Evaluation at timestep 5011 returned a mean returns of -14.999
# Epsilon = 0.4384
# Replay Buffer count: 1930
#  30%|███       | 6014/20000 [03:23<09:54, 23.54it/s]Evaluation at timestep 6014 returned a mean returns of -14.999
# Epsilon = 0.32657500000000006
# Replay Buffer count: 1980
#  35%|███▌      | 7018/20000 [04:06<09:17, 23.28it/s]Evaluation at timestep 7018 returned a mean returns of -14.999
# Epsilon = 0.2135125
# Replay Buffer count: 1990
#  40%|████      | 8003/20000 [04:49<08:59, 22.25it/s]Evaluation at timestep 8003 returned a mean returns of -14.999
# Epsilon = 0.10213749999999999
# Replay Buffer count: 1990
#  45%|████▌     | 9003/20000 [05:33<07:55, 23.11it/s]Evaluation at timestep 9003 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 1990
#  50%|█████     | 10005/20000 [06:17<07:15, 22.96it/s]Evaluation at timestep 10005 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2000
#  55%|█████▌    | 11003/20000 [07:02<06:31, 22.96it/s]Evaluation at timestep 11003 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2000
#  60%|██████    | 12006/20000 [07:46<05:49, 22.87it/s]Evaluation at timestep 12006 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2000
#  65%|██████▌   | 13013/20000 [08:31<05:02, 23.07it/s]Evaluation at timestep 13013 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2000
#  70%|███████   | 14012/20000 [09:15<04:28, 22.26it/s]Evaluation at timestep 14012 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2000
#  75%|███████▌  | 15009/20000 [09:59<03:39, 22.75it/s]Evaluation at timestep 15009 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2000
#  80%|████████  | 16014/20000 [10:44<02:55, 22.71it/s]Evaluation at timestep 16014 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2000
#  85%|████████▌ | 17001/20000 [11:27<02:11, 22.86it/s]Evaluation at timestep 17001 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2000
#  90%|█████████ | 18003/20000 [12:12<01:27, 22.76it/s]Evaluation at timestep 18003 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  95%|█████████▌| 19008/20000 [12:57<00:43, 22.80it/s]Evaluation at timestep 19008 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
# 20011it [13:41, 24.36it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]Evaluation at timestep 20011 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#
#  Run: 5
#
#   5%|▌         | 1089/20000 [00:34<07:20, 42.92it/s]Evaluation at timestep 1089 returned a mean returns of -500.0
# Epsilon = 0.9337375
# Replay Buffer count: 1550
#  11%|█         | 2136/20000 [01:10<10:44, 27.70it/s]Evaluation at timestep 2136 returned a mean returns of -15.999
# Epsilon = 0.7886124999999999
# Replay Buffer count: 1860
#  15%|█▌        | 3025/20000 [01:45<11:04, 25.56it/s]Evaluation at timestep 3025 returned a mean returns of -15.999
# Epsilon = 0.6664375
# Replay Buffer count: 1900
#  20%|██        | 4008/20000 [02:25<10:49, 24.63it/s]Evaluation at timestep 4008 returned a mean returns of -15.999
# Epsilon = 0.553375
# Replay Buffer count: 1940
#  25%|██▌       | 5025/20000 [03:08<10:45, 23.22it/s]Evaluation at timestep 5025 returned a mean returns of -14.999
# Epsilon = 0.4389624999999999
# Replay Buffer count: 2000
#  30%|███       | 6039/20000 [04:01<09:59, 23.28it/s]Evaluation at timestep 6039 returned a mean returns of -500.0
# Epsilon = 0.32533749999999995
# Replay Buffer count: 2010
#  35%|███▌      | 7009/20000 [04:44<09:24, 23.02it/s]Evaluation at timestep 7009 returned a mean returns of -14.999
# Epsilon = 0.21362499999999995
# Replay Buffer count: 2010
#  40%|████      | 8012/20000 [05:28<08:40, 23.01it/s]Evaluation at timestep 8012 returned a mean returns of -14.999
# Epsilon = 0.10033749999999997
# Replay Buffer count: 2010
#  45%|████▌     | 9004/20000 [06:11<07:59, 22.95it/s]Evaluation at timestep 9004 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  50%|█████     | 10009/20000 [06:56<07:28, 22.27it/s]Evaluation at timestep 10009 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  55%|█████▌    | 11000/20000 [07:40<06:34, 22.83it/s]Evaluation at timestep 11000 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  60%|██████    | 12013/20000 [08:24<05:51, 22.73it/s]Evaluation at timestep 12013 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  65%|██████▌   | 13011/20000 [09:09<05:04, 22.94it/s]Evaluation at timestep 13011 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  70%|███████   | 14010/20000 [09:53<04:23, 22.71it/s]Evaluation at timestep 14010 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  75%|███████▌  | 15009/20000 [10:37<03:37, 22.98it/s]Evaluation at timestep 15009 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  80%|████████  | 16002/20000 [11:22<02:54, 22.86it/s]Evaluation at timestep 16002 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  85%|████████▌ | 17008/20000 [12:06<02:11, 22.81it/s]Evaluation at timestep 17008 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2010
#  90%|█████████ | 18013/20000 [12:51<01:26, 22.91it/s]Evaluation at timestep 18013 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2020
#  95%|█████████▌| 19010/20000 [13:35<00:43, 22.57it/s]Evaluation at timestep 19010 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2020
# 20021it [14:20, 23.26it/s]Evaluation at timestep 20021 returned a mean returns of -14.999
# Epsilon = 0.09999999999999998
# Replay Buffer count: 2020

# %%
with open(f'windygrid_eval_{models[j]}.csv', 'ab') as eval:
    for i in range(n_seeds):
        np.savetxt(eval, [returns[i]], delimiter=',')

# %%
with open(f'windygrid_train_{models[j]}.csv', 'ab') as train:
    for i in range(n_seeds):
        np.savetxt(train, [train_returns[i]], delimiter=',')
        np.savetxt(train, [train_times[i]], delimiter=',')

# %%
## Sample Efficiency Evaluation

n_eps = []
n_steps = []
not_solved = []
n_seeds=30

j=7
for i in range(n_seeds):
    print(f"\n Run: {i+1} \n")
    s, e, n = solve(env, 
            CONFIGS[j], 
            fa=function_approximators[j], 
            agent = agents[j],
            target_return=-6,
            op=operator.ge, 
            render=RENDER,
            online=onlines[j])
    env.close()
    n_eps.append(e)
    n_steps.append(s)
    not_solved.append(n)
# Out:
#  Run: 1
#
# Ep. timesteps: 6
# Total timesteps: 762
# Total episodes: 22
# Evaluation mean return: -5.999999999999999
#
#  Run: 2
#
# Ep. timesteps: 6
# Total timesteps: 728
# Total episodes: 19
# Evaluation mean return: -5.999999999999999
#
#  Run: 3
#
# Ep. timesteps: 6
# Total timesteps: 282
# Total episodes: 7
# Evaluation mean return: -5.999999999999999
#
#  Run: 4
#
# Ep. timesteps: 6
# Total timesteps: 425
# Total episodes: 10
# Evaluation mean return: -5.999999999999999
#
#  Run: 5
#
# Ep. timesteps: 6
# Total timesteps: 282
# Total episodes: 10
# Evaluation mean return: -5.999999999999999
#
#  Run: 6
#
# Ep. timesteps: 6
# Total timesteps: 710
# Total episodes: 18
# Evaluation mean return: -5.999999999999999
#
#  Run: 7
#
# Ep. timesteps: 6
# Total timesteps: 1075
# Total episodes: 25
# Evaluation mean return: -5.999999999999999
#
#  Run: 8
#
# Ep. timesteps: 6
# Total timesteps: 521
# Total episodes: 19
# Evaluation mean return: -5.999999999999999
#
#  Run: 9
#
# Ep. timesteps: 6
# Total timesteps: 412
# Total episodes: 12
# Evaluation mean return: -5.999999999999999
#
#  Run: 10
#
# Ep. timesteps: 6
# Total timesteps: 400
# Total episodes: 12
# Evaluation mean return: -5.999999999999999
#
#  Run: 11
#
# Ep. timesteps: 6
# Total timesteps: 651
# Total episodes: 18
# Evaluation mean return: -5.999999999999999
#
#  Run: 12
#
# Ep. timesteps: 6
# Total timesteps: 482
# Total episodes: 15
# Evaluation mean return: -5.999999999999999
#
#  Run: 13
#
#
#  Run: 14
#
# Ep. timesteps: 6
# Total timesteps: 356
# Total episodes: 11
# Evaluation mean return: -5.999999999999999
#
#  Run: 15
#
# Ep. timesteps: 6
# Total timesteps: 200
# Total episodes: 4
# Evaluation mean return: -5.999999999999999
#
#  Run: 16
#
# Ep. timesteps: 6
# Total timesteps: 211
# Total episodes: 6
# Evaluation mean return: -5.999999999999999
#
#  Run: 17
#
# Ep. timesteps: 6
# Total timesteps: 228
# Total episodes: 5
# Evaluation mean return: -5.999999999999999
#
#  Run: 18
#
# Ep. timesteps: 6
# Total timesteps: 267
# Total episodes: 9
# Evaluation mean return: -5.999999999999999
#
#  Run: 19
#
# Ep. timesteps: 6
# Total timesteps: 453
# Total episodes: 14
# Evaluation mean return: -5.999999999999999
#
#  Run: 20
#
# Ep. timesteps: 6
# Total timesteps: 484
# Total episodes: 12
# Evaluation mean return: -5.999999999999999
#
#  Run: 21
#
# Ep. timesteps: 6
# Total timesteps: 277
# Total episodes: 8
# Evaluation mean return: -5.999999999999999
#
#  Run: 22
#
# Ep. timesteps: 6
# Total timesteps: 482
# Total episodes: 12
# Evaluation mean return: -5.999999999999999
#
#  Run: 23
#
# Ep. timesteps: 6
# Total timesteps: 348
# Total episodes: 13
# Evaluation mean return: -5.999999999999999
#
#  Run: 24
#
#
#  Run: 25
#
#
#  Run: 26
#
# Ep. timesteps: 6
# Total timesteps: 264
# Total episodes: 7
# Evaluation mean return: -5.999999999999999
#
#  Run: 27
#
# Ep. timesteps: 6
# Total timesteps: 298
# Total episodes: 11
# Evaluation mean return: -5.999999999999999
#
#  Run: 28
#
# Ep. timesteps: 6
# Total timesteps: 526
# Total episodes: 18
# Evaluation mean return: -5.999999999999999
#
#  Run: 29
#
# Ep. timesteps: 6
# Total timesteps: 448
# Total episodes: 14
# Evaluation mean return: -5.999999999999999
#
#  Run: 30
#
# Ep. timesteps: 6
# Total timesteps: 404
# Total episodes: 10
# Evaluation mean return: -5.999999999999999

# %%
with open(f'windygrid_se-6_{models[j]}.csv', 'ab') as se:
    np.savetxt(se, [n_eps], delimiter=',')
    np.savetxt(se, [n_steps], delimiter=',')
    np.savetxt(se, [not_solved], delimiter=',')

# %%
mean_eps = np.mean(n_eps)
std_eps = np.std(n_eps)
print(f"Average n_eps: {mean_eps}")
print(f"Std n_eps: {std_eps}")
print(f"St.error n_eps: {std_eps/np.sqrt(n_seeds)}")

mean_steps = np.mean(n_steps)
std_steps = np.std(n_steps)
print(f"Average n_steps: {mean_steps}0")
print(f"Std n_steps: {std_steps}")
print(f"St.error n_steps: {std_steps/np.sqrt(n_seeds)}")

print(f"Not solved: {np.sum(not_solved)} runs")
# Out:
# Average n_eps: 21.633333333333333
# Std n_eps: 27.45721924902245
# St.error n_eps: 5.0129794496848845
# Average n_steps: 900.60
# Std n_steps: 1383.9435826651315
# St.error n_steps: 252.67237284673604
# Not solved: 3 runs

# %%
## Training time

times = []
for j in range(8):
        time = train_time(env, 
                CONFIGS[j], 
                fa=function_approximators[j], 
                agent = agents[j],
                online=onlines[j])
        env.close()
        times.append(time)

print(time)
# Out:
# 5005it [00:06, 732.22it/s]
#   3%|▎         | 173/5000 [00:00<00:02, 1637.78it/s]-6
# 5006it [00:03, 1297.35it/s]
#  11%|█▏        | 566/5000 [00:00<00:01, 3382.90it/s]-8
# 100%|██████████| 5000/5000 [00:37<00:00, 134.49it/s]
#  11%|█         | 549/5000 [00:00<00:01, 3684.31it/s]-6
# 5007it [02:02, 40.97it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]-8
# 5001it [03:33, 23.42it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]-6
# 5003it [09:31,  8.75it/s]
#  11%|█         | 531/5000 [00:00<00:01, 2983.59it/s]-6
# 100%|██████████| 5000/5000 [04:40<00:00, 17.83it/s]
#   1%|          | 28/5000 [00:00<00:20, 246.46it/s]-6
# 5004it [00:56, 89.35it/s]                          -6
# 56.0056312084198

# %%
with open(f'simplegrid_times.csv', 'ab') as t:
    np.savetxt(t, [times], delimiter=',')
