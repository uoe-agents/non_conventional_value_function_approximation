# %%
import gym 
import numpy as np
from custom_envs.gridworlds import WindyGridworldEnv, SimpleGridworldEnv
from custom_envs.mountain_car import MountainCarEnv

from function_approximators.function_approximators import NeuralNetwork, LinearModel, DecisionTree, RandomForest, SupportVectorRegressor, KNeighboursRegressor, GaussianProcess, OnlineGaussianProcess
from sklearn.gaussian_process.kernels import RBF, ConstantKernel, RationalQuadratic, Matern
from sklearn.metrics.pairwise import rbf_kernel, chi2_kernel, laplacian_kernel 

from utils.train_utils import train, solve, train_time
from utils.plot_utils import plot_returns

from agents.av_agents import DQNAgent, LinearAgent, FQIAgent, OnlineGaussianProccessAgent

import operator

# %%
function_approximators = [NeuralNetwork, LinearModel, DecisionTree, RandomForest, SupportVectorRegressor, KNeighboursRegressor, GaussianProcess, OnlineGaussianProcess]

agents = [DQNAgent, LinearAgent, *[FQIAgent]*5, OnlineGaussianProccessAgent]

RENDER = False
# env = gym.make("CartPole-v1")
# env = gym.make("Acrobot-v1")
# env = gym.make("MountainCar-v0")
# env = WindyGridworldEnv()
# env = gym.make("LunarLander-v2")
env = SimpleGridworldEnv()
# env = MountainCarEnv()

# %%
# DQN Config
CONFIG_DQN = {
    "episode_length": 20,
    "max_timesteps": 5000,
    "max_time": 30 * 60,
    "eval_freq": 100, 
    "eval_episodes": 10,
    "learning_rate": 0.00075,
    "hidden_size": (32,32),
    "target_update_freq": 20,
    "batch_size": 32,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "plot_loss": False,
    "epsilon": 1,
    "max_deduct": 0.97,
    "decay": 0.25,
    "lr_step_size": 100,
    "lr_gamma": 0.95,
    "max_steps": 20,
    "non_param": False,
}

# Linear Config
CONFIG_LINEAR = {
    "episode_length": 20,
    "max_timesteps": 5000,
    "max_time": 30 * 60,
    "eval_freq": 100, 
    "eval_episodes": 10,
    "learning_rate": 0.02,
    "target_update_freq": 10,
    "batch_size": 32,
    "gamma": 0.99,
    "buffer_capacity": int(1e7),
    "plot_loss": False,
    "epsilon": 1,
    "max_steps": 20,
    "poly_degree": 2,
    "max_deduct": 0.97,
    "decay": 0.5,
    "lr_step_size": 100,
    "lr_gamma": 0.99,
    "non_param": False,
}

# Decision Tree Config
CONFIG_DT = {
    "episode_length": 20,
    "max_timesteps": 5000,
    "max_time": 30 * 60,
    "eval_freq": 100, 
    "eval_episodes": 10,
    "model_save_freq": 250,
    "model_save_capacity": 20,
    "update_freq": 1,
    "batch_size": 512,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.4,
    "max_steps": 20,
    "non_param": True,
    "model_params": {"criterion":"mse","max_depth": 10, "min_samples_split": 20, "min_samples_leaf": 5},
    "feature_names": ["Cart Position", "Cart Velocity", "Pole Angle", "Pole Angular Velocity", "Action: Push Left", "Action: Push Right"],
    "plot_name": "dt_depth=8",
}

# Random Forest Config
CONFIG_RF = {
    "episode_length": 20,
    "max_timesteps": 5000,
    "max_time": 30 * 60,
    "eval_freq": 100, 
    "eval_episodes": 5,
    "model_save_freq": 250,
    "model_save_capacity": 20,
    "update_freq": 5,
    "batch_size": 512,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.4,
    "max_steps": 20,
    "non_param": True,
    "model_params": {"n_estimators": 10,"max_depth": 10, "min_samples_split": 20, "min_samples_leaf": 5},
}

# Support Vector Regressor Config
CONFIG_SVR = {
    "episode_length": 20,
    "max_timesteps": 5000,
    "max_time": 30 * 60,
    "eval_freq": 1000, 
    "eval_episodes": 10,
    "model_save_freq": 250,
    "model_save_capacity": 20,
    "update_freq": 1,
    "batch_size": 512,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.3,
    "max_steps": 20,
    "non_param": True,
    "model_params": {"kernel":"rbf", "degree": 2, "C": 2},
}


# K-Neighbors Regressor Config
CONFIG_KNR = {
    "episode_length": 20,
    "max_timesteps": 5000,
    "max_time": 30 * 60,
    "eval_freq": 100, 
    "eval_episodes": 5,
    "model_save_freq": 250,
    "model_save_capacity": 20,
    "update_freq": 1,
    "batch_size": 256,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.3,
    "max_steps": 20,
    "non_param": True,
    "model_params": {"n_neighbors":7, "weights": "distance", "algorithm": "auto", "leaf_size": 30},
}

# Gaussian Process Config
CONFIG_GP = {
    "episode_length": 20,
    "max_timesteps": 5000,
    "max_time": 30 * 60,
    "eval_freq": 100, 
    "eval_episodes": 5,
    "model_save_freq": 250,
    "model_save_capacity": 20,
    "update_freq": 10,
    "batch_size": 512,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.3,
    "max_steps": 20,
    "non_param": True,
    "model_params": {"alpha": 1e-10, "normalize_y": False, "kernel":  RBF(length_scale=0.08, length_scale_bounds="fixed")},
}

# Online Gaussian Process Config
CONFIG_GP_Online = {
    "episode_length": 20,
    "max_timesteps": 5000,
    "max_time": 30 * 60,
    "eval_freq": 100, 
    "eval_episodes": 10,
    "gamma": 0.99,
    "buffer_capacity": int(1e6),
    "batch_size": 32,
    "epsilon": 1,
    "max_deduct": 0.95,
    "decay": 0.3,
    "max_steps": 20,
    "non_param": True,
    "model_params": {"sigma_0": 0.5, "kernel":  rbf_kernel, "epsilon_tol": 0.05, "basis_limit": 1000},
}

# %%
returns = []
train_returns = []
train_times = []
n_seeds=30

j=0
for i in range(n_seeds):
    print(f"\n Run: {i+1} \n")
    r, _, t, times = train(env, 
            CONFIG_DQN, 
            fa=function_approximators[j], 
            agent = agents[j], 
            render=RENDER,
            online=False)
    env.close()
    returns.append(r)
    train_returns.append(t)
    train_times.append(times)
# Out:
#   2%|▏         | 106/5000 [00:00<00:05, 846.72it/s]
#  Run: 1
#
# Evaluation at timestep 106 returned a mean returns of 20.0
# Epsilon = 0.927056
# Learning rate = 0.00075
#   6%|▌         | 308/5000 [00:00<00:08, 549.06it/s]Evaluation at timestep 208 returned a mean returns of 9.000000000000002
# Epsilon = 0.854112
# Learning rate = 0.0007125
# Evaluation at timestep 308 returned a mean returns of 9.399999999999999
# Epsilon = 0.77496
#   8%|▊         | 410/5000 [00:00<00:08, 555.93it/s]Learning rate = 0.000676875
# Evaluation at timestep 410 returned a mean returns of 9.5
# Epsilon = 0.69736
# Learning rate = 0.0006430312499999999
#  12%|█▏        | 612/5000 [00:01<00:07, 571.44it/s]Evaluation at timestep 500 returned a mean returns of 9.3
# Epsilon = 0.6228640000000001
# Learning rate = 0.0006108796874999999
# Evaluation at timestep 612 returned a mean returns of 9.3
#  14%|█▎        | 680/5000 [00:01<00:08, 495.88it/s]Epsilon = 0.540608
# Learning rate = 0.0005803357031249999
#  15%|█▍        | 740/5000 [00:01<00:09, 457.66it/s]Evaluation at timestep 700 returned a mean returns of 20.0
# Epsilon = 0.47231999999999996
# Learning rate = 0.0005513189179687499
#  18%|█▊        | 912/5000 [00:01<00:08, 486.78it/s]Evaluation at timestep 811 returned a mean returns of 9.3
# Epsilon = 0.38308
# Learning rate = 0.0005237529720703124
# Evaluation at timestep 912 returned a mean returns of 9.3
# Epsilon = 0.3023760000000001
# Learning rate = 0.0004975653234667968
#  22%|██▏       | 1102/5000 [00:02<00:07, 510.76it/s]Evaluation at timestep 1003 returned a mean returns of 13.799999999999999
# Epsilon = 0.23408800000000007
# Learning rate = 0.00047268705729345693
# Evaluation at timestep 1102 returned a mean returns of 20.0
# Epsilon = 0.16036799999999996
#                                                     Learning rate = 0.00044905270442878404
#  25%|██▌       | 1262/5000 [00:02<00:07, 496.55it/s]Evaluation at timestep 1202 returned a mean returns of 20.0
# Epsilon = 0.08276800000000006
# Learning rate = 0.00042660006920734484
#  28%|██▊       | 1402/5000 [00:02<00:06, 521.79it/s]Evaluation at timestep 1302 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0004052700657469776
#  29%|██▉       | 1462/5000 [00:02<00:07, 476.18it/s]Evaluation at timestep 1402 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003850065624596287
#                                                     Evaluation at timestep 1502 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00036575623433664727
# Evaluation at timestep 1602 returned a mean returns of 20.0
#  33%|███▎      | 1662/5000 [00:03<00:06, 483.13it/s]Epsilon = 0.030000000000000027
# Learning rate = 0.0003474684226198149
#  36%|███▌      | 1782/5000 [00:03<00:06, 467.69it/s]Evaluation at timestep 1702 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003300950014888241
#  38%|███▊      | 1902/5000 [00:03<00:07, 429.87it/s]Evaluation at timestep 1802 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003135902514143829
# Evaluation at timestep 1902 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00029791073884366374
#  41%|████      | 2062/5000 [00:04<00:06, 463.77it/s]Evaluation at timestep 2002 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002830152019014805
#  44%|████▍     | 2202/5000 [00:04<00:05, 500.74it/s]Evaluation at timestep 2102 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00026886444180640646
#  45%|████▌     | 2262/5000 [00:04<00:05, 460.23it/s]Evaluation at timestep 2202 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002554212197160861
#  48%|████▊     | 2402/5000 [00:04<00:05, 491.51it/s]Evaluation at timestep 2302 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002426501587302818
#  49%|████▉     | 2462/5000 [00:05<00:05, 450.14it/s]Evaluation at timestep 2402 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00023051765079376771
#  52%|█████▏    | 2602/5000 [00:05<00:04, 486.74it/s]Evaluation at timestep 2502 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002189917682540793
#  53%|█████▎    | 2662/5000 [00:05<00:05, 455.30it/s]Evaluation at timestep 2602 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00020804217984137532
#  56%|█████▌    | 2802/5000 [00:05<00:04, 502.44it/s]Evaluation at timestep 2702 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00019764007084930655
#  57%|█████▋    | 2862/5000 [00:05<00:04, 464.99it/s]Evaluation at timestep 2802 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00018775806730684123
#  60%|██████    | 3002/5000 [00:06<00:03, 524.11it/s]Evaluation at timestep 2902 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00017837016394149914
# Evaluation at timestep 3002 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
#  62%|██████▏   | 3102/5000 [00:06<00:03, 480.24it/s]Learning rate = 0.0001694516557444242
# Evaluation at timestep 3102 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
#  64%|██████▎   | 3182/5000 [00:06<00:03, 488.73it/s]Learning rate = 0.00016097907295720297
#                                                     Evaluation at timestep 3202 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00015293011930934283
# Evaluation at timestep 3302 returned a mean returns of 20.0
#  68%|██████▊   | 3402/5000 [00:06<00:03, 515.98it/s]Epsilon = 0.030000000000000027
# Learning rate = 0.00014528361334387567
#                                                     Evaluation at timestep 3402 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00013801943267668189
# Evaluation at timestep 3502 returned a mean returns of 20.0
#  72%|███████▏  | 3602/5000 [00:07<00:02, 533.72it/s]Epsilon = 0.030000000000000027
# Learning rate = 0.00013111846104284778
# Evaluation at timestep 3602 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
#  73%|███████▎  | 3662/5000 [00:07<00:02, 490.51it/s]Learning rate = 0.0001245625379907054
#  76%|███████▌  | 3802/5000 [00:07<00:02, 502.15it/s]Evaluation at timestep 3702 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0001183344110911701
#  77%|███████▋  | 3862/5000 [00:07<00:02, 448.88it/s]Evaluation at timestep 3802 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00011241769053661159
#  80%|████████  | 4002/5000 [00:08<00:02, 486.86it/s]Evaluation at timestep 3902 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00010679680600978101
#  81%|████████  | 4062/5000 [00:08<00:02, 446.33it/s]Evaluation at timestep 4002 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00010145696570929195
#  84%|████████▎ | 4182/5000 [00:08<00:01, 449.31it/s]Evaluation at timestep 4102 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 9.638411742382735e-05
#  85%|████████▍ | 4242/5000 [00:08<00:01, 405.93it/s]Evaluation at timestep 4202 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 9.156491155263598e-05
#  88%|████████▊ | 4402/5000 [00:09<00:01, 483.42it/s]Evaluation at timestep 4302 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 8.698666597500417e-05
# Evaluation at timestep 4402 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
#  90%|█████████ | 4502/5000 [00:09<00:01, 465.42it/s]Learning rate = 8.263733267625396e-05
# Evaluation at timestep 4502 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 7.850546604244126e-05
#  93%|█████████▎| 4662/5000 [00:09<00:00, 466.92it/s]Evaluation at timestep 4602 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 7.45801927403192e-05
# Evaluation at timestep 4702 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 7.085118310330323e-05
# Evaluation at timestep 4802 returned a mean returns of 20.0
#  98%|█████████▊| 4902/5000 [00:10<00:00, 488.05it/s]Epsilon = 0.030000000000000027
# Learning rate = 6.730862394813807e-05
# Evaluation at timestep 4902 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 6.394319275073117e-05
# 5002it [00:10, 477.63it/s]
#   2%|▏         | 113/5000 [00:00<00:05, 823.18it/s]Evaluation at timestep 5002 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 6.0746033113194604e-05
#
#  Run: 2
#
# Evaluation at timestep 113 returned a mean returns of 8.8
# Epsilon = 0.927832
# Learning rate = 0.00075
#   6%|▌         | 306/5000 [00:00<00:08, 559.00it/s]Evaluation at timestep 205 returned a mean returns of 9.000000000000002
# Epsilon = 0.85256
# Learning rate = 0.0007125
# Evaluation at timestep 306 returned a mean returns of 9.700000000000001
# Epsilon = 0.776512
# Learning rate = 0.000676875
#  10%|█         | 516/5000 [00:00<00:08, 549.15it/s]Evaluation at timestep 409 returned a mean returns of 9.5
# Epsilon = 0.69736
# Learning rate = 0.0006430312499999999
# Evaluation at timestep 504 returned a mean returns of 9.6
# Epsilon = 0.620536
# Learning rate = 0.0006108796874999999
#  14%|█▍        | 707/5000 [00:01<00:07, 545.52it/s]Evaluation at timestep 609 returned a mean returns of 9.8
# Epsilon = 0.536728
# Learning rate = 0.0005803357031249999
# Evaluation at timestep 707 returned a mean returns of 20.0
# Epsilon = 0.4668880000000001
# Learning rate = 0.0005513189179687499
#  17%|█▋        | 862/5000 [00:01<00:08, 485.20it/s]Evaluation at timestep 802 returned a mean returns of 20.0
# Epsilon = 0.39316799999999996
# Learning rate = 0.0005237529720703124
#  20%|██        | 1002/5000 [00:01<00:07, 505.09it/s]Evaluation at timestep 902 returned a mean returns of 20.0
# Epsilon = 0.31556799999999996
# Learning rate = 0.0004975653234667968
#  21%|██        | 1062/5000 [00:02<00:08, 469.58it/s]Evaluation at timestep 1002 returned a mean returns of 20.0
# Epsilon = 0.23796800000000007
# Learning rate = 0.00047268705729345693
#  24%|██▎       | 1182/5000 [00:02<00:08, 462.21it/s]Evaluation at timestep 1102 returned a mean returns of 20.0
# Epsilon = 0.16036799999999996
# Learning rate = 0.00044905270442878404
#  26%|██▌       | 1302/5000 [00:02<00:08, 440.44it/s]Evaluation at timestep 1202 returned a mean returns of 20.0
# Epsilon = 0.08276800000000006
# Learning rate = 0.00042660006920734484
# Evaluation at timestep 1302 returned a mean returns of 20.0
#  28%|██▊       | 1382/5000 [00:02<00:07, 472.67it/s]Epsilon = 0.030000000000000027
# Learning rate = 0.0004052700657469776
#  29%|██▉       | 1442/5000 [00:02<00:08, 440.31it/s]Evaluation at timestep 1402 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003850065624596287
#  32%|███▏      | 1582/5000 [00:03<00:07, 459.33it/s]Evaluation at timestep 1502 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00036575623433664727
#  33%|███▎      | 1642/5000 [00:03<00:08, 418.60it/s]Evaluation at timestep 1602 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003474684226198149
#  36%|███▌      | 1782/5000 [00:03<00:06, 460.14it/s]Evaluation at timestep 1702 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003300950014888241
#  37%|███▋      | 1842/5000 [00:03<00:07, 417.47it/s]Evaluation at timestep 1802 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003135902514143829
#  40%|███▉      | 1982/5000 [00:04<00:06, 454.70it/s]Evaluation at timestep 1902 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00029791073884366374
#  41%|████      | 2042/5000 [00:04<00:07, 420.27it/s]Evaluation at timestep 2002 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002830152019014805
#  44%|████▍     | 2202/5000 [00:04<00:05, 472.70it/s]Evaluation at timestep 2102 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00026886444180640646
#  45%|████▌     | 2262/5000 [00:04<00:06, 452.93it/s]Evaluation at timestep 2202 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002554212197160861
#  48%|████▊     | 2382/5000 [00:05<00:05, 464.59it/s]Evaluation at timestep 2302 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002426501587302818
#  49%|████▉     | 2442/5000 [00:05<00:05, 431.45it/s]Evaluation at timestep 2402 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00023051765079376771
#  52%|█████▏    | 2582/5000 [00:05<00:05, 447.54it/s]Evaluation at timestep 2502 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002189917682540793
#  53%|█████▎    | 2642/5000 [00:05<00:05, 405.29it/s]Evaluation at timestep 2602 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00020804217984137532
#  56%|█████▌    | 2782/5000 [00:05<00:05, 440.34it/s]Evaluation at timestep 2702 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00019764007084930655
#  57%|█████▋    | 2842/5000 [00:06<00:05, 410.58it/s]Evaluation at timestep 2802 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00018775806730684123
#  60%|█████▉    | 2982/5000 [00:06<00:04, 439.61it/s]Evaluation at timestep 2902 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00017837016394149914
#  61%|██████    | 3042/5000 [00:06<00:04, 419.76it/s]Evaluation at timestep 3002 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0001694516557444242
#  64%|██████▎   | 3182/5000 [00:06<00:03, 459.71it/s]Evaluation at timestep 3102 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00016097907295720297
#  66%|██████▌   | 3302/5000 [00:07<00:03, 452.48it/s]Evaluation at timestep 3202 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00015293011930934283
#  67%|██████▋   | 3362/5000 [00:07<00:03, 421.11it/s]Evaluation at timestep 3302 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00014528361334387567
#  70%|██████▉   | 3482/5000 [00:07<00:03, 449.74it/s]Evaluation at timestep 3402 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00013801943267668189
# Evaluation at timestep 3502 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00013111846104284778
# Evaluation at timestep 3602 returned a mean returns of 20.0
#  74%|███████▎  | 3682/5000 [00:08<00:02, 473.43it/s]Epsilon = 0.030000000000000027
# Learning rate = 0.0001245625379907054
#  76%|███████▌  | 3802/5000 [00:08<00:02, 478.25it/s]Evaluation at timestep 3702 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0001183344110911701
#  77%|███████▋  | 3862/5000 [00:08<00:02, 445.20it/s]Evaluation at timestep 3802 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00011241769053661159
#  80%|███████▉  | 3982/5000 [00:08<00:02, 463.96it/s]Evaluation at timestep 3902 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00010679680600978101
#  81%|████████  | 4042/5000 [00:08<00:02, 431.59it/s]Evaluation at timestep 4002 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00010145696570929195
#  84%|████████▎ | 4182/5000 [00:09<00:01, 456.05it/s]Evaluation at timestep 4102 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 9.638411742382735e-05
#  86%|████████▌ | 4302/5000 [00:09<00:01, 441.85it/s]Evaluation at timestep 4202 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 9.156491155263598e-05
# Evaluation at timestep 4302 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 8.698666597500417e-05
#  90%|█████████ | 4502/5000 [00:09<00:01, 459.96it/s]Evaluation at timestep 4402 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 8.263733267625396e-05
#  91%|█████████ | 4562/5000 [00:10<00:01, 414.50it/s]Evaluation at timestep 4502 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 7.850546604244126e-05
#  94%|█████████▎| 4682/5000 [00:10<00:00, 441.11it/s]Evaluation at timestep 4602 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 7.45801927403192e-05
#  95%|█████████▍| 4742/5000 [00:10<00:00, 413.87it/s]Evaluation at timestep 4702 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 7.085118310330323e-05
#  98%|█████████▊| 4882/5000 [00:10<00:00, 459.88it/s]Evaluation at timestep 4802 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 6.730862394813807e-05
#  99%|█████████▉| 4942/5000 [00:10<00:00, 434.98it/s]Evaluation at timestep 4902 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 6.394319275073117e-05
# 5002it [00:11, 452.28it/s]
#   2%|▏         | 108/5000 [00:00<00:05, 879.48it/s]Evaluation at timestep 5002 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 6.0746033113194604e-05
#
#  Run: 3
#
# Evaluation at timestep 108 returned a mean returns of 9.600000000000001
# Epsilon = 0.931712
# Learning rate = 0.00075
#   5%|▌         | 250/5000 [00:00<00:08, 529.22it/s]Evaluation at timestep 203 returned a mean returns of 9.4
# Epsilon = 0.851008
# Learning rate = 0.0007125
#   8%|▊         | 412/5000 [00:00<00:07, 608.25it/s]Evaluation at timestep 312 returned a mean returns of 9.4
# Epsilon = 0.770304
# Learning rate = 0.000676875
# Evaluation at timestep 412 returned a mean returns of 9.1
# Epsilon = 0.695032
# Learning rate = 0.0006430312499999999
#  12%|█▏        | 602/5000 [00:01<00:08, 526.39it/s]Evaluation at timestep 509 returned a mean returns of 9.700000000000001
# Epsilon = 0.620536
# Learning rate = 0.0006108796874999999
# Evaluation at timestep 602 returned a mean returns of 9.3
# Epsilon = 0.543712
# Learning rate = 0.0005803357031249999
#  15%|█▍        | 742/5000 [00:01<00:08, 519.60it/s]Evaluation at timestep 703 returned a mean returns of 9.8
# Epsilon = 0.462232
# Learning rate = 0.0005513189179687499
# Evaluation at timestep 803 returned a mean returns of 9.200000000000001
# Epsilon = 0.3877360000000001
# Learning rate = 0.0005237529720703124
# Evaluation at timestep 911 returned a mean returns of 13.899999999999999
# Epsilon = 0.303152
#  20%|██        | 1000/5000 [00:01<00:07, 528.26it/s]Learning rate = 0.0004975653234667968
# Evaluation at timestep 1000 returned a mean returns of 16.299999999999997
# Epsilon = 0.23796800000000007
# Learning rate = 0.00047268705729345693
#  24%|██▍       | 1213/5000 [00:02<00:07, 538.43it/s]Evaluation at timestep 1101 returned a mean returns of 17.9
# Epsilon = 0.15726399999999996
# Learning rate = 0.00044905270442878404
#  25%|██▌       | 1273/5000 [00:02<00:07, 489.89it/s]Evaluation at timestep 1213 returned a mean returns of 19.6
# Epsilon = 0.07345599999999997
# Learning rate = 0.00042660006920734484
#  28%|██▊       | 1393/5000 [00:02<00:07, 494.11it/s]Evaluation at timestep 1313 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0004052700657469776
#  30%|███       | 1513/5000 [00:02<00:07, 463.98it/s]Evaluation at timestep 1413 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003850065624596287
# Evaluation at timestep 1513 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00036575623433664727
#                                                     Evaluation at timestep 1613 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003474684226198149
# Evaluation at timestep 1713 returned a mean returns of 20.0
#  36%|███▌      | 1793/5000 [00:03<00:06, 498.97it/s]Epsilon = 0.030000000000000027
# Learning rate = 0.0003300950014888241
#  38%|███▊      | 1913/5000 [00:03<00:06, 462.38it/s]Evaluation at timestep 1813 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0003135902514143829
# Evaluation at timestep 1913 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
#  40%|████      | 2013/5000 [00:03<00:05, 513.93it/s]Learning rate = 0.00029791073884366374
#  41%|████▏     | 2073/5000 [00:04<00:06, 477.00it/s]Evaluation at timestep 2013 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002830152019014805
#  44%|████▍     | 2213/5000 [00:04<00:05, 501.96it/s]Evaluation at timestep 2113 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00026886444180640646
#  45%|████▌     | 2273/5000 [00:04<00:05, 464.37it/s]Evaluation at timestep 2213 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002554212197160861
#  48%|████▊     | 2413/5000 [00:04<00:05, 510.94it/s]Evaluation at timestep 2313 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002426501587302818
#  49%|████▉     | 2473/5000 [00:04<00:05, 470.04it/s]Evaluation at timestep 2413 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00023051765079376771
#  52%|█████▏    | 2613/5000 [00:05<00:04, 516.74it/s]Evaluation at timestep 2513 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0002189917682540793
# Evaluation at timestep 2613 returned a mean returns of 20.0
#  53%|█████▎    | 2673/5000 [00:05<00:04, 479.84it/s]Epsilon = 0.030000000000000027
# Learning rate = 0.00020804217984137532
#  56%|█████▌    | 2793/5000 [00:05<00:04, 469.79it/s]Evaluation at timestep 2713 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00019764007084930655
# Evaluation at timestep 2813 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00018775806730684123
# Evaluation at timestep 2913 returned a mean returns of 20.0
#  60%|██████    | 3013/5000 [00:06<00:03, 508.22it/s]Epsilon = 0.030000000000000027
# Learning rate = 0.00017837016394149914
#  61%|██████▏   | 3073/5000 [00:06<00:04, 473.34it/s]Evaluation at timestep 3013 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0001694516557444242
#  64%|██████▍   | 3193/5000 [00:06<00:03, 477.50it/s]Evaluation at timestep 3113 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00016097907295720297
#  65%|██████▌   | 3253/5000 [00:06<00:04, 432.71it/s]Evaluation at timestep 3213 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00015293011930934283
#  67%|██████▋   | 3373/5000 [00:06<00:03, 420.33it/s]Evaluation at timestep 3313 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00014528361334387567
#  70%|██████▉   | 3493/5000 [00:07<00:03, 450.86it/s]Evaluation at timestep 3413 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00013801943267668189
#  72%|███████▏  | 3613/5000 [00:07<00:02, 467.38it/s]Evaluation at timestep 3513 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00013111846104284778
#  73%|███████▎  | 3673/5000 [00:07<00:03, 427.81it/s]Evaluation at timestep 3613 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0001245625379907054
#  76%|███████▌  | 3793/5000 [00:07<00:02, 454.69it/s]Evaluation at timestep 3713 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.0001183344110911701
#  78%|███████▊  | 3913/5000 [00:08<00:02, 471.12it/s]Evaluation at timestep 3813 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00011241769053661159
#  79%|███████▉  | 3973/5000 [00:08<00:02, 438.95it/s]Evaluation at timestep 3913 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00010679680600978101
#  82%|████████▏ | 4093/5000 [00:08<00:01, 455.11it/s]Evaluation at timestep 4013 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 0.00010145696570929195
#  83%|████████▎ | 4153/5000 [00:08<00:01, 423.95it/s]Evaluation at timestep 4113 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 9.638411742382735e-05
#  86%|████████▌ | 4293/5000 [00:09<00:01, 459.28it/s]Evaluation at timestep 4213 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 9.156491155263598e-05
#  88%|████████▊ | 4413/5000 [00:09<00:01, 469.80it/s]Evaluation at timestep 4313 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 8.698666597500417e-05
#  89%|████████▉ | 4473/5000 [00:09<00:01, 437.15it/s]Evaluation at timestep 4413 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 8.263733267625396e-05
#  92%|█████████▏| 4593/5000 [00:09<00:00, 444.55it/s]Evaluation at timestep 4513 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 7.850546604244126e-05
#  93%|█████████▎| 4653/5000 [00:09<00:00, 409.45it/s]Evaluation at timestep 4613 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 7.45801927403192e-05
#  96%|█████████▋| 4813/5000 [00:10<00:00, 471.94it/s]Evaluation at timestep 4713 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 7.085118310330323e-05
#  97%|█████████▋| 4873/5000 [00:10<00:00, 438.15it/s]Evaluation at timestep 4813 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 6.730862394813807e-05
# 100%|█████████▉| 4993/5000 [00:10<00:00, 449.64it/s]Evaluation at timestep 4913 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 6.394319275073117e-05
# 5013it [00:10, 468.30it/s]
#   2%|▏         | 107/5000 [00:00<00:05, 907.02it/s]Evaluation at timestep 5013 returned a mean returns of 20.0
# Epsilon = 0.030000000000000027
# Learning rate = 6.0746033113194604e-05
#
#  Run: 4
#
# Evaluation at timestep 107 returned a mean returns of 9.3
# Epsilon = 0.93016
# Learning rate = 0.00075
#   6%|▌         | 301/5000 [00:00<00:08, 567.43it/s]Evaluation at timestep 210 returned a mean returns of 9.4
# Epsilon = 0.85256
# Learning rate = 0.0007125
# Evaluation at timestep 301 returned a mean returns of 9.100000000000001
# Epsilon = 0.781944
# Learning rate = 0.000676875
#  10%|█         | 504/5000 [00:00<00:07, 568.63it/s]Evaluation at timestep 409 returned a mean returns of 9.3
# Epsilon = 0.6981360000000001
# Learning rate = 0.0006430312499999999
# Evaluation at timestep 504 returned a mean returns of 9.4
# Epsilon = 0.618984
# Learning rate = 0.0006108796874999999
#  14%|█▍        | 712/5000 [00:01<00:07, 556.92it/s]Evaluation at timestep 605 returned a mean returns of 9.3
# Epsilon = 0.54604
# Learning rate = 0.0005803357031249999
# Evaluation at timestep 712 returned a mean returns of 9.500000000000002
# Epsilon = 0.4630080000000001
#  16%|█▌        | 785/5000 [00:01<00:07, 557.09it/s]
# Learning rate = 0.0005513189179687499
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-36eed0e93853> in <module>
#       7 for i in range(n_seeds):
#       8     print(f"\n Run: {i+1} \n")
# ----> 9     r, _, t, times = train(env,
#      10             CONFIG_DQN,
#      11             fa=function_approximators[j],
#
# ~/rl_vfa/utils/train_utils.py in train(env, config, fa, agent, output, render, online)
#      97
#      98             agent.schedule_hyperparameters(timesteps_elapsed, config["max_timesteps"])
# ---> 99             episode_timesteps, train_return, losses = play_episode(
#     100                 env,
#     101                 agent,
#
# ~/rl_vfa/utils/train_utils.py in play_episode(env, agent, replay_buffer, non_param, max_steps, online, batch_size, train, explore, render)
#      49                         agent.update(batch)
#      50                 else:
# ---> 51                     loss = agent.update(batch)["q_loss"]
#      52                     losses.append(loss)
#      53         elif train:
#
# ~/rl_vfa/agents/av_agents.py in update(self, batch)
#      58         Q = self.model(batch.states)
#      59         # Obtain the action values of the actions selected in the batch
# ---> 60         q_current = Q.gather(1, batch.actions.long())
#      61
#      62         # Obtain the action values given the next states in the batch from critics_target network
#
# KeyboardInterrupt:

# %%
with open(f'cartpole_eval_Gaussian Process (On+).csv', 'ab') as eval:
    for i in range(n_seeds):
        np.savetxt(eval, [returns[i]], delimiter=',')

# %%
with open(f'cartpole_train_Gaussian Process (On+).csv', 'ab') as train:
    for i in range(n_seeds):
        np.savetxt(train, [train_returns[i]], delimiter=',')
        np.savetxt(train, [train_times[i]], delimiter=',')

# %%
n_eps = []
n_steps = []
not_solved = []
n_seeds=30

j=7
for i in range(n_seeds):
    print(f"\n Run: {i+1} \n")
    s, e, n = solve(env, 
            CONFIG_GP_Online, 
            fa=function_approximators[j], 
            agent = agents[j],
            target_return=195,
            op=operator.ge, 
            render=RENDER,
            online=True)
    env.close()
    n_eps.append(e)
    n_steps.append(s)
    not_solved.append(n)
# Out:
#  Run: 1
#
# Ep. timesteps: 200
# Total timesteps: 3434
# Total episodes: 90
# Evaluation mean return: 197.4
#
#  Run: 2
#
# Ep. timesteps: 200
# Total timesteps: 1388
# Total episodes: 53
# Evaluation mean return: 195.9
#
#  Run: 3
#
# Ep. timesteps: 200
# Total timesteps: 360
# Total episodes: 14
# Evaluation mean return: 200.0
#
#  Run: 4
#
# Ep. timesteps: 200
# Total timesteps: 11329
# Total episodes: 168
# Evaluation mean return: 196.7
#
#  Run: 5
#
# Ep. timesteps: 200
# Total timesteps: 5993
# Total episodes: 134
# Evaluation mean return: 200.0
#
#  Run: 6
#
# Ep. timesteps: 200
# Total timesteps: 2807
# Total episodes: 82
# Evaluation mean return: 200.0
#
#  Run: 7
#
# Ep. timesteps: 200
# Total timesteps: 1367
# Total episodes: 49
# Evaluation mean return: 200.0
#
#  Run: 8
#
# Ep. timesteps: 200
# Total timesteps: 874
# Total episodes: 37
# Evaluation mean return: 200.0
#
#  Run: 9
#
# Ep. timesteps: 200
# Total timesteps: 2291
# Total episodes: 78
# Evaluation mean return: 200.0
#
#  Run: 10
#
# Ep. timesteps: 200
# Total timesteps: 740
# Total episodes: 28
# Evaluation mean return: 195.5
#
#  Run: 11
#
# Ep. timesteps: 200
# Total timesteps: 637
# Total episodes: 24
# Evaluation mean return: 200.0
#
#  Run: 12
#
# Ep. timesteps: 200
# Total timesteps: 1481
# Total episodes: 58
# Evaluation mean return: 200.0
#
#  Run: 13
#
# Ep. timesteps: 200
# Total timesteps: 1472
# Total episodes: 55
# Evaluation mean return: 200.0
#
#  Run: 14
#
# Ep. timesteps: 200
# Total timesteps: 1091
# Total episodes: 45
# Evaluation mean return: 200.0
#
#  Run: 15
#
# Ep. timesteps: 200
# Total timesteps: 2618
# Total episodes: 83
# Evaluation mean return: 200.0
#
#  Run: 16
#
# Ep. timesteps: 200
# Total timesteps: 1694
# Total episodes: 64
# Evaluation mean return: 200.0
#
#  Run: 17
#
# Ep. timesteps: 200
# Total timesteps: 1487
# Total episodes: 53
# Evaluation mean return: 200.0
#
#  Run: 18
#
# Ep. timesteps: 200
# Total timesteps: 2449
# Total episodes: 95
# Evaluation mean return: 200.0
#
#  Run: 19
#
# Ep. timesteps: 200
# Total timesteps: 15841
# Total episodes: 167
# Evaluation mean return: 195.0
#
#  Run: 20
#
#
#  Run: 21
#
# Ep. timesteps: 200
# Total timesteps: 1105
# Total episodes: 45
# Evaluation mean return: 200.0
#
#  Run: 22
#
# Ep. timesteps: 200
# Total timesteps: 75
# Total episodes: 3
# Evaluation mean return: 200.0
#
#  Run: 23
#
# Ep. timesteps: 200
# Total timesteps: 1669
# Total episodes: 60
# Evaluation mean return: 200.0
#
#  Run: 24
#
# Ep. timesteps: 200
# Total timesteps: 1309
# Total episodes: 53
# Evaluation mean return: 195.0
#
#  Run: 25
#
# Ep. timesteps: 194
# Total timesteps: 18818
# Total episodes: 199
# Evaluation mean return: 195.20000000000002
#
#  Run: 26
#
# Ep. timesteps: 200
# Total timesteps: 4057
# Total episodes: 105
# Evaluation mean return: 200.0
#
#  Run: 27
#
# Ep. timesteps: 200
# Total timesteps: 3785
# Total episodes: 96
# Evaluation mean return: 199.8
#
#  Run: 28
#
# Ep. timesteps: 200
# Total timesteps: 3539
# Total episodes: 105
# Evaluation mean return: 200.0
#
#  Run: 29
#
# Ep. timesteps: 200
# Total timesteps: 1553
# Total episodes: 59
# Evaluation mean return: 200.0
#
#  Run: 30
#
# Ep. timesteps: 200
# Total timesteps: 454
# Total episodes: 18
# Evaluation mean return: 200.0

# %%
with open(f'cartpole_se195_Gaussian Process Online.csv', 'ab') as se:
    np.savetxt(se, [n_eps], delimiter=',')
    np.savetxt(se, [n_steps], delimiter=',')
    np.savetxt(se, [not_solved], delimiter=',')

# %%
mean_eps = np.mean(n_eps)
std_eps = np.std(n_eps)
print(f"Average n_eps: {mean_eps}")
print(f"Std n_eps: {std_eps}")
print(f"St.error n_eps: {std_eps/np.sqrt(n_seeds)}")

mean_steps = np.mean(n_steps)
std_steps = np.std(n_steps)
print(f"Average n_steps: {mean_steps}0")
print(f"Std n_steps: {std_steps}")
print(f"St.error n_steps: {std_steps/np.sqrt(n_seeds)}")

print(f"Not solved: {np.sum(not_solved)} runs")
# Out:
# Average n_eps: 77.13333333333334
# Std n_eps: 47.77219088781906
# St.error n_eps: 8.721968856900416
# Average n_steps: 3211.03333333333330
# Std n_steps: 4515.506184126967
# St.error n_steps: 824.4148652001386
# Not solved: 1 runs

# %%
j = 10
time = train_time(env, 
        CONFIG_GP_Online, 
        fa=function_approximators[j], 
        agent = agents[j],
        online=True)
env.close()

print(time)
# Out:
# 20029it [06:32, 51.03it/s]200.0
# 392.48629212379456
